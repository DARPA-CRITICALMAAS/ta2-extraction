# %%
import pandas as pd
import json
import re
import csv
import os
import copy
from datetime import datetime
import glob
import numpy as np
from reportlab.lib import colors
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle, Spacer, Paragraph
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# %%
def collect_json_files(directory):
    json_files = []
    for file_path in glob.glob(os.path.join(directory, '*.json')):
         json_files.append(os.path.basename(file_path))
    return json_files

# %%
def read_csv_to_dict(file_path):
    data_dict_list = []
    
    with open(file_path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        for row in csv_reader:
            data_dict_list.append(dict(row))
    
    return data_dict_list

# %%
def select_keys(d, keys):
    selected = {}
    for key in keys:
        value = d
        for subkey in key.split('.'):
            if isinstance(value, dict) and subkey in value:
                value = value[subkey]
            else:
                value = None
                break
        selected[key] = value
    return selected

# %%
 def get_deposit_types(json_data):   
    minmod_deposit_types = read_csv_to_dict("./codes/minmod_deposit_types.csv")
    deposit_id = {}
    for key in minmod_deposit_types:
        deposit_id[key['Minmod ID']] = key['Deposit type']

    data = []
    for item in json_data['deposit_type']:
        row = {
            "deposit type": deposit_id[item.split('/')[-1]],
        }
        data.append(row)

    deposit_types = pd.DataFrame(data)
    return deposit_types

# %%
def get_document_ref(json_data):
    if 'MineralInventory' in json_data and json_data['MineralInventory']:
        if 'reference' in json_data['MineralInventory'][0] and 'document' in json_data['MineralInventory'][0]['reference']:
            document_ref = json_data['MineralInventory'][0]['reference']['document']
            document_df = pd.DataFrame.from_dict(document_ref, orient='index').T
            return document_df
    # If the 'document' key does not exist, or if any of the necessary keys are missing, return None or raise an error
    return pd.DataFrame()

# %%
def get_mineral_site(json_data):
    selected_keys = ["source_id", "name", "location_info.location","location_info.country", 
                     "location_info.crs", "location_info.state_or_province"]

    mineral_site = pd.DataFrame(select_keys(json_data, selected_keys), index=[0])
    return mineral_site

# %%
def get_mineral_inventory(json_data):
    minmod_commodities = read_csv_to_dict("./codes/minmod_commodities.csv")
    commodities = {}
    for key in minmod_commodities:
        commodities[key['minmod_id']] = key['CommodityinGeoKb']

    minmod_units = read_csv_to_dict("./codes/minmod_units.csv")
    correct_units = {}
    for key in minmod_units:
        correct_units[key['minmod_id']] =  key['unit name']

    # Extracting required fields with cutoff_unit and cutoff_value
    data = []
    for item in json_data['MineralInventory']:
        row = {
            "zone": item.get("zone"),
            "page_number": item["reference"]["page_info"][0]["page"],
            "commodity": commodities[item.get("commodity").split('/')[-1]],
            "category": item["category"][0].split('/')[-1],
            "ore_unit": correct_units[item["ore"]["ore_unit"].split('/')[-1]],
            "ore_value": item["ore"]["ore_value"],
            "grade_unit": correct_units[item["grade"]["grade_unit"].split('/')[-1]],
            "grade_value": item["grade"]["grade_value"],
            "cutoff_unit": correct_units[item["cutoff_grade"].get("grade_unit").split('/')[-1]] if "cutoff_grade" in item else None,
            "cutoff_value": item["cutoff_grade"].get("grade_value") if "cutoff_grade" in item else None
        }
        data.append(row)

    # Creating DataFrame
    mineral_inventory = pd.DataFrame(data)
    return mineral_inventory

# %%
def create_pdf_with_tables(dataframes, output_file):
    doc = SimpleDocTemplate(output_file, pagesize=letter)
    elements = []
    styles = getSampleStyleSheet()

    # Define a style for wrapped text inside table cells
    cell_style = styles['Normal']
    cell_style.wordWrap = 'CJK'  # Use 'CJK' word wrapping which wraps on any character

    for name, dataframe in dataframes.items():
        # Add title above each table
        title_style = ParagraphStyle('TitleStyle', parent=styles['Normal'], alignment=0, fontName='Helvetica-Bold')  # Left alignment and bold font
        title = Paragraph(name, title_style)
        elements.append(title)
        
        # Convert DataFrame to list of lists
        # Ensure each cell in the dataframe is wrapped with a Paragraph object
    
        if len(dataframe.columns)>0:
            table_data = [[Paragraph(str(cell), cell_style) for cell in dataframe.columns]]  # Header row
            for row in dataframe.values.tolist():
                table_data.append([Paragraph(str(cell), cell_style) for cell in row])  # Data rows

            # Calculate the width of the table to fit within the page width
            table_width = doc.width * 0.9  

            # Create table with column width calculated to fit the page

            table = Table(table_data, colWidths=[table_width / len(dataframe.columns)] * len(dataframe.columns))

            # Add style to the table
            style = TableStyle([
                ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
                ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
                ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
                ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
                ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),  # Set font to Helvetica for table data
                ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
                ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
                ('GRID', (0, 0), (-1, -1), 1, colors.black),
                ('TEXTCOLOR', (0, 0), (-1, -1), colors.black),  # Set text color to black
                ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black),  # Set inner grid color
                ('BOX', (0, 0), (-1, -1), 0.25, colors.black),  # Draw a border around each cell
                ('VALIGN', (0, 0), (-1, -1), 'MIDDLE'),  # Center text vertically
                ('ALIGN', (0, 0), (-1, -1), 'CENTER'),  # Center text horizontally
                ('FONTNAME', (0, 0), (-1, -1), 'Helvetica'),  # Set font to Helvetica for all cells
                ('SIZE', (0, 0), (-1, -1), 9),  # Set initial font size to 9
                ('TEXTFONT', (0, 0), (-1, -1), 'Helvetica'),  # Set font to Helvetica for all cells
                ('LEADING', (0, 0), (-1, -1), 9),  # Set initial leading (line spacing) to 9
                ('BACKGROUND', (0, 0), (-1, 0), colors.gray)  # Set header row background color
            ])

            table.setStyle(style)
            elements.append(table)

            # Add space between tables
            elements.append(Spacer(1, 24))

        # Build PDF with all tables
    doc.build(elements)

# %%
folder_path = './extracted/extractions/'
files = collect_json_files(folder_path)
print(files)
# Out:
# ['Hakkira_Zn_4-2011_summary_20240110_111100.json', 'Mehdiabad_Zn_3-2005_summary_20231222_093735.json', 'Horne_5_Cu_Zn_Au_Ag_10-2017_FS_summary_20240118_133338.json', 'Macmillan_Pass_Zn_Pb_Ag_7-2018_PEA_summary_20240119_130630.json', 'La_Negra_Ag_Cu_Pb_Zn_1-2015_OM_summary_20240124_115513.json', 'Pine_Point_Zn_Pb_8-2007_v_1_summary_20240118_135326.json', 'McIlvenna_Bay_Cu_Zn_Ag_Au_1-2015_PEA_summary_20240119_132335.json', 'Scotia_Pb_Zn_7-2020_summary_20240112_110458.json', 'La_Negra_Ag_Cu_Pb_Zn_5-2013_OM_summary_20240124_151004.json', 'Jubilee_Zn_Pb_11-2007_summary_20240111_154103.json', 'Hakkari_Zn_7-2013_summary_20240116_133821.json', 'Tufanbeyli_Zn_7-2013_summary_20240112_115329.json', 'Hakkari_Zn_3-2010_summary_20240109_104541.json', 'Scarlet_Zn_Pb_10-2011_summary_20240111_161945.json', 'Cozamin_Zn_Cu_Ag_8-2014_OM_summary_20240117_130906.json', 'Scotia_Pb_Zn_7-2006_summary_20240111_164607.json', 'Prairie2017.json', 'Bleiberg_Pb_Zn_5-2017_summary_20231221_101020.json', 'Penasquito_Zn_Pb_Ag_Au_3-2016_OM_summary_20240205_105558.json', 'Murray_Brook_Cu_Pb_Zn_Au_Ag_7-2013_PEA_summary_20240122_153218.json', 'Reocin_Zn_3-2002_summary_20231222_091703.json', 'BYP_Au_6-2011_summary_20240117_114025.json', 'Tufanbeyli_Zn_7-2011_summary_20240112_111917.json', 'Klaza_Pb_Zn_Ag_Au_6-2018_PEA_summary_20240119_105136.json', 'Daniels_Harbour_Zn_12-2017_summary_20240109_100508.json', 'Penasquito_Au_Ag_Pb_Zn_8-2018_OM_summary_20240202_131212.json', 'McIlvenna_Bay_Cu_Zn_Ag_Au_12-2014_PEA_summary_20240119_134344.json', 'Pine_Point_Zn_Pb_12-2007_summary_20240111_160025.json', 'Lalor_Zn_Cu_3-2017_OM_summary_20240130_130223.json', 'Prairie_Creek_Zn_Pb_Ag_5-2016_PFS_summary_20231221_113216.json', 'Bongará_Zn_3-2019_summary_20240102_130243.json', 'Nash_Creek_and_Superjack_Zn_Pb_Ag_6-2018_PEA_summary_20240130_135504.json', 'Nuestra_Senora_Zn_Ag_4-2013_PEA_summary_20240201_124310.json', 'Bolivar_Cu_Zn_Au_5-2013_OM_summary_20240117_110444.json', 'Tulsequah_Chief_Cu_Pb_Zn_Au_Ag_1-2013_FS_summary_20240118_143523.json', 'Klaza_Au_Ag_Pb_Zn_2-2016_PEA_summary_20240118_164102.json', '777_Cu_Zn_Ag_Au_10-2012_OM_summary_20240116_143617.json']

# %%
for file in files:
    print(f"working on file: {file}")
    file_path = folder_path + file
    filename = file[:-3]
    with open(file_path, 'r') as f:
        # Load the JSON data into a Python dictionary
        data = json.load(f)

    # Now 'data' contains the contents of the JSON file
    json_data = data['MineralSite'][0]
    document_df = get_document_ref(json_data)
    mineral_site = get_mineral_site(json_data)
    mineral_inventory = get_mineral_inventory(json_data)
    deposit_types = get_deposit_types(json_data)
    data_dict = {'Document Reference':document_df, 'Mineral Site ':mineral_site, 
                 'Mineral Inventory':mineral_inventory, 'Deposit Types': deposit_types}
    create_pdf_with_tables(data_dict, f'./created_pdf/{filename}.pdf')
    print(f"Finished file {file}")
# Out:
# working on file: Hakkira_Zn_4-2011_summary_20240110_111100.json
#                                                title  \
# 0  NI 43-101 Technical Report on the Hakkari Zinc...
#
#                              uri  \
# 0  file-YzC1Hy8G0xIipW8IcbgH0fuj
#
#                                           authors  year month  \
# 0  [Mike Robertson, Dr Brendan Clarke, Mike Hall]  2011     4
#
#                                          description
# 0  The mineral properties that form the HZP repre...
# Finished file Hakkira_Zn_4-2011_summary_20240110_111100.json
# working on file: Mehdiabad_Zn_3-2005_summary_20231222_093735.json
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/N958IUC2
#
#                                              title uri month  year
# 0  mehdiabad zinc project – information memorandum         3  2005
# Finished file Mehdiabad_Zn_3-2005_summary_20231222_093735.json
# working on file: Horne_5_Cu_Zn_Au_Ag_10-2017_FS_summary_20240118_133338.json
#                                       title  \
# 0  Feasibility Study - Horne 5 Gold Project
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/88W9PUZ9
#
#                                              authors  year month  \
# 0  [Colin Hardie P.Eng., Pierre Lacombe P.Eng., C...  2017    10
#
#                                          description
# 0  The document is a NI 43-101 Technical Report d...
# Finished file Horne_5_Cu_Zn_Au_Ag_10-2017_FS_summary_20240118_133338.json
# working on file: Macmillan_Pass_Zn_Pb_Ag_7-2018_PEA_summary_20240119_130630.json
#                                                title  \
# 0  NI 43-101 Technical Report Macmillan Pass Proj...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/FF4M7ZNB
#
#                                              authors  year month  \
# 0  [Michael Makarenko P. Eng., Kelly McLeod P. En...  2018     7
#
#                                          description
# 0  This NI 43-101 Technical Report pertains to th...
# Finished file Macmillan_Pass_Zn_Pb_Ag_7-2018_PEA_summary_20240119_130630.json
# working on file: La_Negra_Ag_Cu_Pb_Zn_1-2015_OM_summary_20240124_115513.json
#                                                title  \
# 0  Technical Report Minera La Negra Property Quer...
#
#                                              authors  year month  \
# 0  [G.Z. Mosher P.Geo., C Keogh P.Eng, A Riles MA...  2015     1
#
#                                          description
# 0  The report, prepared by AMC Mining Consultants...
# Finished file La_Negra_Ag_Cu_Pb_Zn_1-2015_OM_summary_20240124_115513.json
# working on file: Pine_Point_Zn_Pb_8-2007_v_1_summary_20240118_135326.json
#                                                title  \
# 0  NI 43-101 Technical Report: Pine Point Project...
#
#                                          authors  year month  \
# 0  [Fred Barnard Ph.D., Robert L. Sandefur P.E.]  2007     8
#
#                                          description
# 0  The report provides technical details on Pine ...
# Finished file Pine_Point_Zn_Pb_8-2007_v_1_summary_20240118_135326.json
# working on file: McIlvenna_Bay_Cu_Zn_Ag_Au_1-2015_PEA_summary_20240119_132335.json
#                                                title  \
# 0  Preliminary Economic Assessment Technical Repo...
#
#                                              authors  year month  \
# 0  [Michael Makarenko P. Eng., Darren Kennard P. ...  2015     1
#
#                                          description
# 0  A technical report assessing the economic pote...
# Finished file McIlvenna_Bay_Cu_Zn_Ag_Au_1-2015_PEA_summary_20240119_132335.json
# working on file: Scotia_Pb_Zn_7-2020_summary_20240112_110458.json
#                                                title  \
# 0  Scotia Mine Pre-Feasibility Study Technical Re...
#
#                                         doi                            uri  \
# 0  https://w3id.org/usgs/z/4530692/QI4SWBKV  file-bmKC9mgaTbUlmngx2z7xsAV0
#
#                                              authors  year month  \
# 0  [Timothy Carew P.Geo., Tony Gilman M.Sc. P.Eng...  2020     7
#
#                                          description
# 0  This is a technical report following the Natio...
# Finished file Scotia_Pb_Zn_7-2020_summary_20240112_110458.json
# working on file: La_Negra_Ag_Cu_Pb_Zn_5-2013_OM_summary_20240124_151004.json
#                                                title  \
# 0  Technical Report of the La Negra Mine Querétar...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/U7RE352Z
#
#                                              authors  year month  \
# 0  [Baltazar Solano-Rico GEOL. ENG. M.SC. MMSA 01...  2013     5
#
#                                          description
# 0  The document is a technical report on the La N...
# Finished file La_Negra_Ag_Cu_Pb_Zn_5-2013_OM_summary_20240124_151004.json
# working on file: Jubilee_Zn_Pb_11-2007_summary_20240111_154103.json
#                                            title  \
# 0  TECHNICAL REPORT ON MINERAL RESOURCE ESTIMATE
#
#                                         doi                            uri  \
# 0  https://w3id.org/usgs/z/4530692/V6TB3XSJ  file-ZTfAKgxVKg250uSpH8reBlJX
#
#                                              authors  year month  \
# 0  [Michael P. Cullen M.Sc. P.Geo., Paul J. Téniè...  2007    11
#
#                                          description
# 0  Technical report on the Jubilee Zinc-Lead Depo...
# Finished file Jubilee_Zn_Pb_11-2007_summary_20240111_154103.json
# working on file: Hakkari_Zn_7-2013_summary_20240116_133821.json
#                                                title  \
# 0  NI 43-101 Technical Report on the Hakkari Zinc...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/N4NGZN8C
#
#                                     authors  year month  \
# 0  [Mike Robertson, Mike Hall, Ewald Meyer]  2013     7
#
#                                          description
# 0  A National Instrument 43-101 Technical Report ...
# Finished file Hakkari_Zn_7-2013_summary_20240116_133821.json
# working on file: Tufanbeyli_Zn_7-2013_summary_20240112_115329.json
#                                                title  \
# 0  NI 43-101 Technical Report on the Tufanbeyli Z...
#
#                                         doi uri  \
# 0  https://w3id.org/usgs/z/4530692/WAF3S5H7
#
#                                     authors  year month  \
# 0  [Mike Robertson, Mike Hall, Ewald Meyer]  2013     7
#
#                                          description
# 0  This revised report was prepared by The MSA Gr...
# Finished file Tufanbeyli_Zn_7-2013_summary_20240112_115329.json
# working on file: Hakkari_Zn_3-2010_summary_20240109_104541.json
# Finished file Hakkari_Zn_3-2010_summary_20240109_104541.json
# working on file: Scarlet_Zn_Pb_10-2011_summary_20240111_161945.json
# Finished file Scarlet_Zn_Pb_10-2011_summary_20240111_161945.json
# working on file: Cozamin_Zn_Cu_Ag_8-2014_OM_summary_20240117_130906.json
#                                                title  \
# 0  NI 43-101 Technical Report on the Cozamin Mine...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/EHWKWRKK
#
#                                              authors  year month  \
# 0  [Patrick Andrieux PhD. P.Eng., Dave Hallman PE...  2014     8
#
#                                          description
# 0  This NI 43-101 Technical Report on the Cozamin...
# Finished file Cozamin_Zn_Cu_Ag_8-2014_OM_summary_20240117_130906.json
# working on file: Scotia_Pb_Zn_7-2006_summary_20240111_164607.json
# Finished file Scotia_Pb_Zn_7-2006_summary_20240111_164607.json
# working on file: Prairie2017.json
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/R8GBBQJN
#
#                                                title uri month  year
# 0  Prairie Creek Property Feasibility Study NI 43...         9  2015
# Finished file Prairie2017.json
# working on file: Bleiberg_Pb_Zn_5-2017_summary_20231221_101020.json
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/CGFRUCNS
#
#                                title uri month  year
# 0  Bleiberg Project Technical Report         5  2017
# Finished file Bleiberg_Pb_Zn_5-2017_summary_20231221_101020.json
# working on file: Penasquito_Zn_Pb_Ag_Au_3-2016_OM_summary_20240205_105558.json
#                                                title  \
# 0  Peñasquito Polymetallic Operations Zacatecas S...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/5SV8IBCW
#
#                                              authors  year month  \
# 0  [Mr Dan Redmond P.Geo., Dr Sally Goodman P.Geo...  2016     3
#
#                                          description
# 0  NI 43-101 Technical Report for the Peñasquito ...
# Finished file Penasquito_Zn_Pb_Ag_Au_3-2016_OM_summary_20240205_105558.json
# working on file: Murray_Brook_Cu_Pb_Zn_Au_Ag_7-2013_PEA_summary_20240122_153218.json
#                                                title  \
# 0  TECHNICAL REPORT AND PRELIMINARY ECONOMIC ASSE...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/3HEHSEU8
#
#                                              authors  year month  \
# 0  [Mr. Eugene Puritch P.Eng., Mr. Gerald Harron ...  2013     7
#
#                                          description
# 0  A technical report and preliminary economic as...
# Finished file Murray_Brook_Cu_Pb_Zn_Au_Ag_7-2013_PEA_summary_20240122_153218.json
# working on file: Reocin_Zn_3-2002_summary_20231222_091703.json
#          id                                              title month  year
# 0  doc_id_0  competent person’s report for the reocín mine ...     3  2002
# Finished file Reocin_Zn_3-2002_summary_20231222_091703.json
# working on file: BYP_Au_6-2011_summary_20240117_114025.json
#                                                title  \
# 0  Technical Report on the BYP Property Hunan Pro...
#
#                                         doi                  authors  year  \
# 0  https://w3id.org/usgs/z/4530692/RHWSF8W4  [Randal Cullen P. Geo.]  2011
#
#   month                                        description
# 0     6  This report for Silvercorp Metals Inc. provide...
# Finished file BYP_Au_6-2011_summary_20240117_114025.json
# working on file: Tufanbeyli_Zn_7-2011_summary_20240112_111917.json
#                                                title  \
# 0  NI 43-101 Technical Report on the Tufanbeyli Z...
#
#                                         doi uri                      authors  \
# 0  https://w3id.org/usgs/z/4530692/DE5B2V5V      [Mike Robertson, Mike Hall]
#
#    year month                                        description
# 0  2011     7  Technical report prepared by The MSA Group on ...
# Finished file Tufanbeyli_Zn_7-2011_summary_20240112_111917.json
# working on file: Klaza_Pb_Zn_Ag_Au_6-2018_PEA_summary_20240119_105136.json
#                                                title  \
# 0  Technical Report Describing Updated Diamond Dr...
#
#                                              authors  year month  \
# 0  [A. Ross Ph.D. P.Geo. (BC) P.Geol. (AB), I. Ki...  2018     6
#
#                                          description
# 0  This Technical Report discloses the results of...
# Finished file Klaza_Pb_Zn_Ag_Au_6-2018_PEA_summary_20240119_105136.json
# working on file: Daniels_Harbour_Zn_12-2017_summary_20240109_100508.json
# Finished file Daniels_Harbour_Zn_12-2017_summary_20240109_100508.json
# working on file: Penasquito_Au_Ag_Pb_Zn_8-2018_OM_summary_20240202_131212.json
#                                                title  \
# 0  Peñasquito Polymetallic Operations Zacatecas S...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/I2BCG764
#
#                                              authors  year month  \
# 0  [Mr. Victor Vdovin P.Eng., Dr. Guillermo Parej...  2018     6
#
#                                          description
# 0  This is a NI 43-101 technical report for the P...
# Finished file Penasquito_Au_Ag_Pb_Zn_8-2018_OM_summary_20240202_131212.json
# working on file: McIlvenna_Bay_Cu_Zn_Ag_Au_12-2014_PEA_summary_20240119_134344.json
#                                                title  \
# 0  Preliminary Economic Assessment Technical Repo...
#
#                                              authors  year month  \
# 0  [Michael Makarenko, Darren Kennard, Matt Bende...  2014    12
#
#                                          description
# 0  This report provides an economic assessment of...
# Finished file McIlvenna_Bay_Cu_Zn_Ag_Au_12-2014_PEA_summary_20240119_134344.json
# working on file: Pine_Point_Zn_Pb_12-2007_summary_20240111_160025.json
#                 title                                       doi  \
# 0  Pine Point Project  https://w3id.org/usgs/z/4530692/JU49QKUZ
#
#                              uri  \
# 0  file-Ag42ZKlL93vWaIpW5vWqseqk
#
#                                              authors  year month  \
# 0  [Fred Barnard Ph.D., Steven Milne P.E., Robert...  2007    12
#
#                                          description
# 0  NI 43-101 Technical Report on the Pine Point P...
# Finished file Pine_Point_Zn_Pb_12-2007_summary_20240111_160025.json
# working on file: Lalor_Zn_Cu_3-2017_OM_summary_20240130_130223.json
#                                        title  \
# 0  Lalor Mine Form 43-101F1 Technical Report
#
#                                         doi                 authors  year  \
# 0  https://w3id.org/usgs/z/4530692/BSRX4ZKD  [Robert Carter P.Eng.]  2017
#
#   month                                        description
# 0     3  The report details the technical and forward-l...
# Finished file Lalor_Zn_Cu_3-2017_OM_summary_20240130_130223.json
# working on file: Prairie_Creek_Zn_Pb_Ag_5-2016_PFS_summary_20231221_113216.json
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/SDZT38KU
#
#                                                title uri month  year
# 0  Prairie Creek Property Prefeasibility Update N...         2  2016
# Finished file Prairie_Creek_Zn_Pb_Ag_5-2016_PFS_summary_20231221_113216.json
# working on file: Bongará_Zn_3-2019_summary_20240102_130243.json
#                                          id              title uri month  year
# 0  https://w3id.org/usgs/z/4530692/9PXBT6Z9  Bongará Zn 3-2019         1  2019
# Finished file Bongará_Zn_3-2019_summary_20240102_130243.json
# working on file: Nash_Creek_and_Superjack_Zn_Pb_Ag_6-2018_PEA_summary_20240130_135504.json
#                                                title  \
# 0  Technical Report and Preliminary Economic Asse...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/V2BAGHTT
#
#                                              authors  year month  \
# 0  [Eugene Puritch, D. Grant Feasby, Alfred S. Ha...  2018     6
#
#                                          description
# 0  This report provides a technical review and pr...
# Finished file Nash_Creek_and_Superjack_Zn_Pb_Ag_6-2018_PEA_summary_20240130_135504.json
# working on file: Nuestra_Senora_Zn_Ag_4-2013_PEA_summary_20240201_124310.json
#                                                title  \
# 0  Technical Report and Preliminary Economic Asse...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/SUCAJNPT
#
#                                              authors  year month  \
# 0  [Thomas L. Dyer P.E., Steven Ristorcelli C. P....  2013     4
#
#                                          description
# 0  The document presents a technical report and p...
# Finished file Nuestra_Senora_Zn_Ag_4-2013_PEA_summary_20240201_124310.json
# working on file: Bolivar_Cu_Zn_Au_5-2013_OM_summary_20240117_110444.json
#                                        title  \
# 0  NI 43-101 TECHNICAL REPORT - BOLÍVAR MINE
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/MGZFU4VF
#
#                                              authors  year month  \
# 0  [Donald E. Hulse P.E. SME-RM, Zachary Black SM...  2013     5
#
#                                          description
# 0  This NI 43-101 technical report is related to ...
# Finished file Bolivar_Cu_Zn_Au_5-2013_OM_summary_20240117_110444.json
# working on file: Tulsequah_Chief_Cu_Pb_Zn_Au_Ag_1-2013_FS_summary_20240118_143523.json
#                       title                     authors  year month  \
# 0  TULSEQUAH CHIEF PROPERTY  [JDS Energy & Mining Inc.]  2013     1
#
#                                          description
# 0  This technical report summarizes the results o...
# Finished file Tulsequah_Chief_Cu_Pb_Zn_Au_Ag_1-2013_FS_summary_20240118_143523.json
# working on file: Klaza_Au_Ag_Pb_Zn_2-2016_PEA_summary_20240118_164102.json
#                                                title  \
# 0  Technical Report and PEA for the Klaza Au-Ag D...
#
#                                         doi  \
# 0  https://w3id.org/usgs/z/4530692/4AAUD2HB
#
#                                              authors  year month  \
# 0  [B Borntraeger P.Eng (BC), C Martin C.Eng (UK)...  2016     2
#
#                                          description
# 0  AMC Mining Consultants (Canada) Ltd. was commi...
# Finished file Klaza_Au_Ag_Pb_Zn_2-2016_PEA_summary_20240118_164102.json
# working on file: 777_Cu_Zn_Ag_Au_10-2012_OM_summary_20240116_143617.json
#                                  title  \
# 0  777 Mine NI 43-101 Technical Report
#
#                                         doi                            uri  \
# 0  https://w3id.org/usgs/z/4530692/42HZRAH5  file-bmg8E9x8w1opLWP0pfey0Loq
#
#                                              authors  year month  \
# 0  [Brett Pearson P. Geo., Darren Lyhkun P. Eng.,...  2012    10
#
#                                          description
# 0  Technical report for the 777 Mine located in F...
# Finished file 777_Cu_Zn_Ag_Au_10-2012_OM_summary_20240116_143617.json

# %%
import json
import pandas as pd
from collections import Counter
import sys
import os
from datetime import datetime
from fuzzywuzzy import fuzz
sys.path.append(os.path.abspath('../../'))


from extraction_package import genericFunctions as generic

# %% [markdown]
# # Functions

# %%
def normalize_unit_values(value):
    if not isinstance(value, str):
        return ""
    if value == '':
        return ""
    if value == "%":
        return 'Q201'

    minmod_units = generic.read_csv_to_dict("../../codes/minmod_units.csv")
    correct_units = {}
    for key in minmod_units:
        correct_units[key['unit name']] = key['minmod_id']
        correct_units[key['unit aliases']] = key['minmod_id']


    found_value = generic.find_best_match(value, list(correct_units.keys())) 
    # print(f"original: {value} found_value: {found_value}")
    if found_value != "" and found_value is not None:
        # print(f"Output: {correct_units[found_value]}")
        return correct_units[found_value]
    else:
        return value


def normalize_location(value, code_file):
    if not isinstance(value, str) or value == '':
        return ""
    minmod_country = generic.read_csv_to_dict(f"../../codes/{code_file}.csv")
    # print(minmod_country[0])

    correct_units = {}
    for key in minmod_country:
        correct_units[key['name']] = key['\ufeffminmod_id']

    # print(correct_units)
    # Find the best match using the provided function
    found_value = generic.find_best_match(value, list(correct_units.keys()))

    if found_value:
        return correct_units[found_value]
    else:
        return value

def remove_words(text, words_to_remove):
    for word in words_to_remove:
        text = text.replace(word, '')  
    return text.strip()  

def normalize_string_names(gt, predicted, threshold=80):
    words_to_remove = ['property', 'project']
    normalized_list = []
    
    # Preprocess `gt` and `predicted` by removing unwanted words and converting to lowercase
    gt_normalized = [remove_words(gt_name.lower(), words_to_remove) for gt_name in gt]
    predicted_normalized = [remove_words(p_name.lower(), words_to_remove) for p_name in predicted]
    
    for p_name, original_p_name in zip(predicted_normalized, predicted):
        matched = False
        for gt_name in gt_normalized:
            similarity = fuzz.partial_ratio(p_name, gt_name)
            # print("Here is the similarity score: ", similarity)
            if similarity >= threshold:
                normalized_list.append(gt[gt_normalized.index(gt_name)])
                matched = True
                break  
        if not matched:
            normalized_list.append(original_p_name)
    
    return normalized_list

# %%
 def clean_value(value):
    if isinstance(value, list):
        if value == [''] or value == [0.0]:
            return []
    return value
     
def extract_data(path_to_file):
    # Open the JSON file and load data
    with open(path_to_file, 'r') as file:
        data = json.load(file)

    # print(data)
    # Get location info

    loc = {
        'mining_site_name': [data[0].get('name', '')],
        'country_observed_name': [
            normalize_location(country['observed_name'], "country")
            for country in data[0]['location_info'].get('country', [])
        ],
        'state_or_province_observed_name': [
            normalize_location(state['observed_name'], "state_or_province")
            for state in data[0]['location_info'].get('state_or_province', [])
        ]
    }

    # Get reference info
    # print(data[0]['mineral_inventory'][0]['reference'])
    ref = {
        'authors': data[0]['reference'][0]['document'].get('authors',""),
        'year': [data[0]['reference'][0]['document'].get('year',"")],
        'month': [data[0]['reference'][0]['document'].get('month',"")]
    }



    # Initialize lists for mineral resource info
    commodity_observed_name = []
    category_observed_name = []
    ore_unit_observed_name = []
    ore_value = []
    grade_unit_observed_name = []
    grade_value = []
    cutoff_grade_unit_observed_name = []
    cutoff_grade_value = []
    contained_metal = []
    zone = []


    # Extract mineral resource data
    for d in data[0].get('mineral_inventory', []):
        commodity_observed_name.append(d.get('commodity', {}).get('observed_name', ''))
        category = d.get('category', [])
        if category:
            category_observed_name.append(category[0].get('observed_name', ''))
        else:
            category_observed_name.append('')
            
        ## change ore value to make sure its correct            
        ore_unit_temp = normalize_unit_values(d.get('ore', {}).get('unit', {}).get('observed_name', ''))
        ore_value_temp = d.get('ore', {}).get('value', 0.0)


        if ore_unit_temp.lower() == 'q202':
            ore_unit_temp = 'q200'
            ore_value_temp *= 1_000_000

        # Append the updated values to the lists
        ore_unit_observed_name.append(ore_unit_temp)
        ore_value.append(ore_value_temp)

        
        grade_unit_observed_name.append(normalize_unit_values(d.get('grade', {}).get('unit', {}).get('observed_name', '')))
        grade_value.append(d.get('grade', {}).get('value', 0.0))
        cutoff_grade_unit_observed_name.append(normalize_unit_values(d.get('cutoff_grade', {}).get('unit', {}).get('observed_name', '')))
        cutoff_grade_value.append(d.get('cutoff_grade', {}).get('value', 0.0))

        
        contained_metal.append(d.get('contained_metal', 0.0))
        zone.append(d.get('zone', ''))
    

    mineral_inventory = {
        'commodity_observed_name': clean_value(commodity_observed_name),
        'category_observed_name': clean_value(category_observed_name),
        'ore_unit_observed_name': clean_value(ore_unit_observed_name),
        'ore_value': clean_value(ore_value),
        'grade_unit_observed_name': clean_value(grade_unit_observed_name),
        'grade_value': clean_value(grade_value),
        'cutoff_grade_unit_observed_name': clean_value(cutoff_grade_unit_observed_name),
        'cutoff_grade_value': clean_value(cutoff_grade_value),
        'contained_metal': clean_value(contained_metal),
        'zone': clean_value(zone)
    }


    # Convert the dictionary into a DataFrame and remove duplicates
    inv_df = pd.DataFrame(mineral_inventory)
    inv_df = inv_df.drop_duplicates()

    # Convert the DataFrame back to a dictionary format
    min_inv_dict = inv_df.to_dict('list')

    # Return location, reference, and mineral inventory data
    return loc, ref, min_inv_dict


def calculate_precision_and_recall(predictions, ground_truth):
    ground_truth_normalized = [str(commodity).strip().lower() for commodity in ground_truth]
    predictions_normalized = [str(commodity).strip().lower() for commodity in predictions]
    
    # Use Counter to handle duplicates
    truth_counter = Counter(ground_truth_normalized)
    prediction_counter = Counter(predictions_normalized)
    print("----------------------------------------------------")
    print(f"Truth_count = {truth_counter}\nprediction counter: {prediction_counter}\n")
    
    # Calculate true positives
    true_positives = truth_counter & prediction_counter  # Intersection of two counters
    num_true_positives = sum(true_positives.values())
    print(f"Number of tp: {num_true_positives}\n\n ")
    false_positives = prediction_counter - truth_counter
    num_false_positives = sum(false_positives.values())
    print(f"Number of FP: {num_false_positives}\n\n ")
    print("----------------------------------------------------")
    # Calculate precision and recall
    num_predictions = sum(prediction_counter.values())
    num_truth = sum(truth_counter.values())
    precision = num_true_positives / num_predictions if num_predictions else 0
    recall = num_true_positives / num_truth if num_truth else 0
    
    return precision, recall, num_true_positives, num_false_positives, num_truth

# %%
def run(report_name, minimal_or_complete, append_date, commodity_folder):
    folder_name = report_name.split("_")[0]
    gt_path = '../data/gt/'+ commodity_folder + "/" + folder_name + '/' + minimal_or_complete + '.json'
    ex_path = '../data/extracted/'+ commodity_folder + "/" + report_name + append_date + '.json'
    
    gt_loc, gt_ref, gt_inv_dict = extract_data(gt_path)
    ex_loc, ex_ref, ex_inv_dict = extract_data(ex_path)
    
    
    print(f"Locations: \nGround Truth: \n{gt_loc}\nExtracted:\n{ex_loc}\n\n")
    print(f"Reference: \nGround Truth: \n{gt_ref}\nExtracted:\n{ex_ref}\n\n")

    print(f"Mineral Inventory: \nGround Truth:{len(gt_inv_dict['commodity_observed_name'])}\nExtracted:{len(ex_inv_dict['commodity_observed_name'])}\n\n")
    
    if len(gt_inv_dict['commodity_observed_name']) > 0 and len(ex_inv_dict['commodity_observed_name']) > 0: 
        gt_merged_dict = {**gt_loc, **gt_ref, **gt_inv_dict}
        ex_merged_dict = {**ex_loc, **ex_ref, **ex_inv_dict}
    else:
        print("No Mineral Inventory")
        return None
    
    res = {}
    for k, v in gt_merged_dict.items():
        if "authors" in k or "mining_site_name" in k:
            actual = list(v)
            predicted = normalize_string_names(v, ex_merged_dict[k])
        elif "value" in k or "contained_metal" in k:
            actual = [round(val, 1) for val in v] 
            predicted = [round(val, 1) for val in ex_merged_dict[k]]
        else:    
            actual = list(v)
            predicted = list(ex_merged_dict[k])
        print(f"Key: {k}")

        
        precision, recall, num_true_positives, num_false_positives, num_truth = calculate_precision_and_recall(predicted, actual)
        res[k] = {'Precision':precision,'Recall':recall, 'TP count': num_true_positives, 'FP count': num_false_positives, "GT count": num_truth}
    report = pd.DataFrame(res).T
    report_path = '../data/gt/'+ commodity_folder + "/" + folder_name + '/' + minimal_or_complete+"_"+'report.csv'
    report.to_csv(report_path, index=True)
    return report

# %%
def write_multiple_reports(Note, report_names, minimal_or_complete, commodity, append_date, current_date):
  
    overall_report = pd.DataFrame()
    minimal_or_complete='minimal'
    sum_columns = ['TP count', 'GT count', 'FP count']
    average_columns = ['Precision', 'Recall']
    for report_name in report_names:
        print(f"Looking at: {report_name}\n")
        report = run(report_name, minimal_or_complete, append_date, commodity)
        print(f"report: \n {report} \n")
        # doing a run without 
        if report is not None:
        
            if overall_report.empty:
                for col in average_columns+sum_columns:
                    overall_report[col] = report[col]
                list_of_reports = report_name
                
            else:
                list_of_reports += ", " + report_name
                for col in average_columns:
                    overall_report[col] = (overall_report[col] * (len(overall_report) - 1) + report[col]) / len(overall_report)
            
                    for col in sum_columns:
                        overall_report[col] += report[col]
                        
        
            overall_report['Calculated Precision from TP/FP'] = overall_report['TP count'] / (overall_report['TP count'] + overall_report['FP count'])
            overall_report['Calculated Recall from TP/FP'] = overall_report['TP count'] / overall_report['GT count']
            overall_report['Added report'] = list_of_reports
            overall_report['note'] = Note

    
    ## at the end
    rename_dict = {col: f"Averaged {col}" for col in average_columns}
    rename_dict.update({col: f"Total {col}" for col in sum_columns})

    overall_report = overall_report.rename(columns=rename_dict)
    overall_report_path = f'../data/gt/{commodity}/{commodity}_overall_report_{current_date}.csv'
    overall_report.to_csv(overall_report_path, index=True)

# %% [markdown]
# # Run

# %%
### Run one Report
# report_name = '02771a5d21ae0aca3c5bfe28f1b0c73eebe1790745adcf42cc10105946c31add6e_NI_43-101_Technical_Report_for_the_Nunavik_Project_in_North_America_dated_April_2010_summary'
# minimal_or_complete='minimal'
# report = run(report_name, minimal_or_complete, append_date)

# %%
### Run for multiple reports
Note = """Testing new prompts:

    """
commodity = "nickel"
folder_path = f"../data/extracted/{commodity}/"
report_names = [
    '_summary'.join(file.split('_summary')[:-1]) + '_summary'
    for file in os.listdir(folder_path)
    if file.endswith('.json')
]
append_date = "_20241028"

current_date = datetime.today().strftime('%Y%m%d')
write_multiple_reports(Note, report_names, minimal_or_complete, commodity, append_date, current_date)
# Out:
# Looking at: 0200a1c6d2cfafeb485d815d95966961d4c119e8662b8babec74e05b59ba4759d2_NI_43-101_Technical_Report_for_the_Turnagain_Project_in_North_America_dated_March_2007_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['Turnagain Nickel Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2654']}
# Extracted:
# {'mining_site_name': ['Turnagain Nickel Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2654']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['Ronald G. Simpson'], 'year': [2007], 'month': [3]}
# Extracted:
# {'authors': ['Ronald G. Simpson'], 'year': [2007], 'month': [3]}
#
#
# Mineral Inventory:
# Ground Truth:28
# Extracted:26
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'turnagain nickel project': 1})
# prediction counter: Counter({'turnagain nickel project': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2654': 1})
# prediction counter: Counter({'q2654': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'ronald g. simpson': 1})
# prediction counter: Counter({'ronald g. simpson': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2007': 1})
# prediction counter: Counter({'2007': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'3': 1})
# prediction counter: Counter({'3': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'nickel': 14, 'cobalt': 14})
# prediction counter: Counter({'nickel': 18, 'cobalt': 8})
#
# Number of tp: 22
#
#
# Number of FP: 4
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'indicated': 10, 'inferred': 10, 'measured': 6, 'measured+indicated': 2})
# prediction counter: Counter({'indicated': 8, 'inferred': 8, 'measured': 6, 'measured+indicated': 4})
#
# Number of tp: 24
#
#
# Number of FP: 2
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 28})
# prediction counter: Counter({'q200': 26})
#
# Number of tp: 26
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'37629000.0': 2, '390934000.0': 2, '428563000.0': 2, '742923000.0': 2, '11295000.0': 2, '115290000.0': 2, '143283000.0': 2, '26335000.0': 2, '205131000.0': 2, '394394000.0': 2, '61305000.0': 2, '182743000.0': 2, '9207000.0': 2, '22503000.0': 2})
# prediction counter: Counter({'37629000.0': 2, '390934000.0': 2, '428563000.0': 2, '742923000.0': 2, '37629.0': 2, '390934.0': 2, '428563.0': 2, '742923.0': 2, '11295000.0': 1, '115290000.0': 1, '143283000.0': 1, '26335000.0': 1, '205131000.0': 1, '394394000.0': 1, '61305000.0': 1, '182743000.0': 1, '9207000.0': 1, '22503000.0': 1})
#
# Number of tp: 18
#
#
# Number of FP: 8
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 28})
# prediction counter: Counter({'q201': 26})
#
# Number of tp: 26
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.2': 14, '0.0': 14})
# prediction counter: Counter({'0.2': 17, '0.0': 8, '0.1': 1})
#
# Number of tp: 22
#
#
# Number of FP: 4
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 28})
# prediction counter: Counter({'q201': 26})
#
# Number of tp: 26
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.1': 28})
# prediction counter: Counter({'0.1': 26})
#
# Number of tp: 26
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'86546.7': 1, '4139.2': 1, '860054.8': 1, '43002.7': 1, '942838.6': 1, '47141.9': 1, '1634430.6': 1, '81721.5': 1, '23719.5': 1, '1016.5': 1, '242109.0': 1, '10376.1': 1, '315222.6': 1, '12895.5': 1, '63204.0': 1, '2896.8': 1, '492314.4': 1, '22564.4': 1, '907106.2': 1, '43383.3': 1, '122610.0': 1, '7969.6': 1, '365486.0': 1, '21929.2': 1, '20255.4': 1, '1012.8': 1, '54007.2': 1, '2475.3': 1})
# prediction counter: Counter({'63969.3': 1, '664587.8': 1, '728557.1': 1, '1262969.1': 1, '4139.2': 1, '43002.7': 1, '47141.9': 1, '81721.5': 1, '86.5': 1, '860.1': 1, '942.8': 1, '1634.4': 1, '4.1': 1, '43.0': 1, '47.1': 1, '81.7': 1, '18072.0': 1, '184464.0': 1, '214924.5': 1, '44769.5': 1, '348722.7': 1, '670469.8': 1, '98088.0': 1, '292388.8': 1, '17493.3': 1, '40505.4': 1})
#
# Number of tp: 4
#
#
# Number of FP: 22
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'': 8, 'northwest domain 1': 6, 'horsetrail domain 2+3': 6, 'hatzl domain 4+5': 4, 'duffy domain 6': 4})
# prediction counter: Counter({'': 8, 'northwest': 3, 'horsetrail': 3, 'measured': 2, 'indicated': 2, 'measured + indicated': 2, 'inferred': 2, 'hatzl': 2, 'duffy': 2})
#
# Number of tp: 8
#
#
# Number of FP: 18
#
#
# ----------------------------------------------------
# report:
#                                   Precision    Recall  TP count  FP count  \
# mining_site_name                  1.000000  1.000000       1.0       0.0
# country_observed_name             1.000000  1.000000       1.0       0.0
# state_or_province_observed_name   1.000000  1.000000       1.0       0.0
# authors                           1.000000  1.000000       1.0       0.0
# year                              1.000000  1.000000       1.0       0.0
# month                             1.000000  1.000000       1.0       0.0
# commodity_observed_name           0.846154  0.785714      22.0       4.0
# category_observed_name            0.923077  0.857143      24.0       2.0
# ore_unit_observed_name            1.000000  0.928571      26.0       0.0
# ore_value                         0.692308  0.642857      18.0       8.0
# grade_unit_observed_name          1.000000  0.928571      26.0       0.0
# grade_value                       0.846154  0.785714      22.0       4.0
# cutoff_grade_unit_observed_name   1.000000  0.928571      26.0       0.0
# cutoff_grade_value                1.000000  0.928571      26.0       0.0
# contained_metal                   0.153846  0.142857       4.0      22.0
# zone                              0.307692  0.285714       8.0      18.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               1.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name              28.0
# category_observed_name               28.0
# ore_unit_observed_name               28.0
# ore_value                            28.0
# grade_unit_observed_name             28.0
# grade_value                          28.0
# cutoff_grade_unit_observed_name      28.0
# cutoff_grade_value                   28.0
# contained_metal                      28.0
# zone                                 28.0
#
# Looking at: 02f973c7f9d847a305032fa4ec221182d8aa7e4e44677bc78d114c9c6d47cdfb08_NI_43-101_Technical_Report_for_the_Marathon_Project_in_North_America_dated_October_2006_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['Marathon PGM-CU Property'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
# Extracted:
# {'mining_site_name': ['MARATHON PGM-CU PROPERTY'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q4202']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['Tim Mann', ' Eugene Puritch', ' David Orava', 'Al Hayden', ' Tracy Armstrong', ' Wayne Ewert'], 'year': [2006], 'month': [6]}
# Extracted:
# {'authors': ['Tim Mann', 'Eugene Puritch', 'David Orava', 'Al Hayden', 'Tracy Armstrong', 'Wayne Ewert'], 'year': [2006], 'month': [6]}
#
#
# Mineral Inventory:
# Ground Truth:32
# Extracted:44
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'marathon pgm-cu property': 1})
# prediction counter: Counter({'marathon pgm-cu property': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2661': 1})
# prediction counter: Counter({'q4202': 1})
#
# Number of tp: 0
#
#
# Number of FP: 1
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'tim mann': 1, 'eugene puritch': 1, 'david orava': 1, 'al hayden': 1, 'tracy armstrong': 1, 'wayne ewert': 1})
# prediction counter: Counter({'tim mann': 1, 'eugene puritch': 1, 'david orava': 1, 'al hayden': 1, 'tracy armstrong': 1, 'wayne ewert': 1})
#
# Number of tp: 6
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2006': 1})
# prediction counter: Counter({'2006': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'6': 1})
# prediction counter: Counter({'6': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'copper': 8, 'gold': 8, 'platinum': 8, 'palladium': 8})
# prediction counter: Counter({'copper': 11, 'gold': 11, 'platinum': 11, 'palladium': 11})
#
# Number of tp: 32
#
#
# Number of FP: 12
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'': 16, 'measured': 4, 'indicated': 4, 'measured+indicated': 4, 'inferred': 4})
# prediction counter: Counter({'inferred': 20, 'probable': 12, 'measured': 4, 'indicated': 4, 'measured+indicated': 4})
#
# Number of tp: 16
#
#
# Number of FP: 28
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 32})
# prediction counter: Counter({'q200': 44})
#
# Number of tp: 32
#
#
# Number of FP: 12
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'18953000.0': 4, '20964000.0': 4, '39917000.0': 4, '4634000.0': 4, '49459000.0': 4, '3780000.0': 4, '4764000.0': 4, '58003000.0': 4})
# prediction counter: Counter({'0.0': 16, '18953000.0': 4, '20964000.0': 4, '39917000.0': 4, '4634000.0': 4, '49459000.0': 4, '3780000.0': 4, '4764000.0': 4})
#
# Number of tp: 28
#
#
# Number of FP: 16
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q203': 24, 'q201': 8})
# prediction counter: Counter({'q203': 33, 'q201': 11})
#
# Number of tp: 32
#
#
# Number of FP: 12
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.3': 9, '0.1': 8, '1.1': 4, '0.2': 4, '0.4': 3, '0.9': 2, '0.7': 1, '1.0': 1})
# prediction counter: Counter({'0.1': 16, '0.3': 8, '0.2': 6, '0.4': 4, '1.1': 4, '0.0': 3, '0.9': 1, '0.7': 1, '1.0': 1})
#
# Number of tp: 30
#
#
# Number of FP: 14
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q212': 16, '': 16})
# prediction counter: Counter({'': 28, 'q206': 16})
#
# Number of tp: 16
#
#
# Number of FP: 28
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'12.0': 16, '0.0': 16})
# prediction counter: Counter({'0.0': 28, '12.0': 16})
#
# Number of tp: 32
#
#
# Number of FP: 12
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'68799.4': 1, '72954.7': 1, '141705.4': 1, '14272.7': 1, '18573.9': 1, '22012.2': 1, '40715.3': 1, '5699.8': 1, '51741.7': 1, '61843.8': 1, '113763.4': 1, '15245.9': 1, '202607.6': 1, '222218.4': 1, '425116.0': 1, '49259.4': 1, '163214.7': 1, '12096.0': 1, '7622.4': 1, '179809.3': 1, '44513.1': 1, '2646.0': 1, '4764.0': 1, '52202.7': 1, '123647.5': 1, '6804.0': 1, '17150.4': 1, '145007.5': 1, '455022.8': 1, '24948.0': 1, '45734.4': 1, '527827.3': 1})
# prediction counter: Counter({'0.0': 16, '68799.4': 1, '72954.7': 1, '141705.4': 1, '14272.7': 1, '18573.9': 1, '22012.2': 1, '40715.3': 1, '5699.8': 1, '51741.7': 1, '61843.8': 1, '113763.4': 1, '15245.9': 1, '202607.6': 1, '222218.4': 1, '425116.0': 1, '49259.4': 1, '163214.7': 1, '12096.0': 1, '7622.4': 1, '44513.1': 1, '2646.0': 1, '4764.0': 1, '123647.5': 1, '6804.0': 1, '17150.4': 1, '455022.8': 1, '24948.0': 1, '45734.4': 1})
#
# Number of tp: 28
#
#
# Number of FP: 16
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'': 16, 'north': 4, 'south': 4, 'south west': 4, 'total': 4})
# prediction counter: Counter({'': 16, 'north': 4, 'south': 4, 'south west': 4, 'north pit': 4, 'south pit': 4, 'south west pit': 4, 'total': 4})
#
# Number of tp: 32
#
#
# Number of FP: 12
#
#
# ----------------------------------------------------
# report:
#                                   Precision  Recall  TP count  FP count  \
# mining_site_name                  1.000000  1.0000       1.0       0.0
# country_observed_name             1.000000  1.0000       1.0       0.0
# state_or_province_observed_name   0.000000  0.0000       0.0       1.0
# authors                           1.000000  1.0000       6.0       0.0
# year                              1.000000  1.0000       1.0       0.0
# month                             1.000000  1.0000       1.0       0.0
# commodity_observed_name           0.727273  1.0000      32.0      12.0
# category_observed_name            0.363636  0.5000      16.0      28.0
# ore_unit_observed_name            0.727273  1.0000      32.0      12.0
# ore_value                         0.636364  0.8750      28.0      16.0
# grade_unit_observed_name          0.727273  1.0000      32.0      12.0
# grade_value                       0.681818  0.9375      30.0      14.0
# cutoff_grade_unit_observed_name   0.363636  0.5000      16.0      28.0
# cutoff_grade_value                0.727273  1.0000      32.0      12.0
# contained_metal                   0.636364  0.8750      28.0      16.0
# zone                              0.727273  1.0000      32.0      12.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               6.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name              32.0
# category_observed_name               32.0
# ore_unit_observed_name               32.0
# ore_value                            32.0
# grade_unit_observed_name             32.0
# grade_value                          32.0
# cutoff_grade_unit_observed_name      32.0
# cutoff_grade_value                   32.0
# contained_metal                      32.0
# zone                                 32.0
#
# Looking at: 0275b5be425dad03ece21eaa64ebc388d765b47ed001e4956f494978c11214f37d_NI_43-101_Technical_Report_for_the_Thunder_Bay_North_Project_in_North_America_dated_October_2010_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['Thunder Bay North Polymetallic Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
# Extracted:
# {'mining_site_name': ['Thunder Bay North Polymetallic Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['Greg Kulla', ' David G. Thomas', ' Lynton Gormely', ' Ted Eggleston', ' Stella Searston'], 'year': [2010], 'month': [10]}
# Extracted:
# {'authors': ['Greg Kulla', 'David G. Thomas', 'Lynton Gormely', 'Ted Eggleston', 'Stella Searston'], 'year': [2010], 'month': [10]}
#
#
# Mineral Inventory:
# Ground Truth:32
# Extracted:32
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'thunder bay north polymetallic project': 1})
# prediction counter: Counter({'thunder bay north polymetallic project': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2661': 1})
# prediction counter: Counter({'q2661': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'greg kulla': 1, 'david g. thomas': 1, 'lynton gormely': 1, 'ted eggleston': 1, 'stella searston': 1})
# prediction counter: Counter({'greg kulla': 1, 'david g. thomas': 1, 'lynton gormely': 1, 'ted eggleston': 1, 'stella searston': 1})
#
# Number of tp: 5
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2010': 1})
# prediction counter: Counter({'2010': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'10': 1})
# prediction counter: Counter({'10': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'platinum': 4, 'palladium': 4, 'rhodium': 4, 'gold': 4, 'silver': 4, 'copper': 4, 'nickel': 4, 'cobalt': 4})
# prediction counter: Counter({'platinum': 4, 'palladium': 4, 'rhodium': 4, 'gold': 4, 'silver': 4, 'copper': 4, 'nickel': 4, 'cobalt': 4})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'indicated': 16, 'inferred': 16})
# prediction counter: Counter({'indicated': 16, 'inferred': 16})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 32})
# prediction counter: Counter({'q200': 32})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'8015000.0': 8, '53000.0': 8, '1046000.0': 8, '213000.0': 8})
# prediction counter: Counter({'8015000.0': 8, '53000.0': 8, '1046000.0': 8, '213000.0': 8})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q203': 24, 'q201': 8})
# prediction counter: Counter({'q203': 20, 'q201': 12})
#
# Number of tp: 28
#
#
# Number of FP: 4
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.1': 7, '0.2': 5, '1.6': 3, '1.0': 2, '0.3': 2, '142.0': 2, '1.1': 1, '0.9': 1, '0.0': 1, '1.5': 1, '2.4': 1, '0.4': 1, '171.0': 1, '1.4': 1, '1.3': 1, '1.9': 1, '158.0': 1})
# prediction counter: Counter({'0.1': 7, '0.0': 5, '0.2': 5, '1.6': 3, '1.0': 2, '0.3': 2, '1.1': 1, '1.4': 1, '0.9': 1, '1.5': 1, '1.3': 1, '2.4': 1, '1.9': 1, '0.4': 1})
#
# Number of tp: 28
#
#
# Number of FP: 4
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q203': 32})
# prediction counter: Counter({'q203': 32})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.6': 16, '1.9': 16})
# prediction counter: Counter({'0.6': 16, '1.9': 16})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'86562.0': 1, '81753.0': 1, '4007.5': 1, '5610.5': 1, '128240.0': 1, '20839.0': 1, '14427.0': 1, '11381300.0': 1, '508.8': 1, '471.7': 1, '21.2': 1, '37.1': 1, '848.0': 1, '116.6': 1, '95.4': 1, '75260.0': 1, '16945.2': 1, '15690.0': 1, '836.8': 1, '1150.6': 1, '25104.0': 1, '4079.4': 1, '2510.4': 1, '1788660.0': 1, '2982.0': 1, '2747.7': 1, '127.8': 1, '191.7': 1, '4047.0': 1, '724.2': 1, '489.9': 1, '336540.0': 1})
# prediction counter: Counter({'0.0': 2, '86562.0': 1, '508.8': 1, '16945.2': 1, '2982.0': 1, '81753.0': 1, '471.7': 1, '15690.0': 1, '2747.7': 1, '4007.5': 1, '21.2': 1, '836.8': 1, '127.8': 1, '5610.5': 1, '37.1': 1, '1150.6': 1, '191.7': 1, '128240.0': 1, '848.0': 1, '25104.0': 1, '4047.0': 1, '20839.0': 1, '116.6': 1, '4079.4': 1, '724.2': 1, '14427.0': 1, '95.4': 1, '2510.4': 1, '489.9': 1, '801.5': 1, '104.6': 1})
#
# Number of tp: 28
#
#
# Number of FP: 4
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'open pit': 16, 'underground': 16})
# prediction counter: Counter({'open pit': 16, 'underground': 16})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# report:
#                                   Precision  Recall  TP count  FP count  \
# mining_site_name                     1.000   1.000       1.0       0.0
# country_observed_name                1.000   1.000       1.0       0.0
# state_or_province_observed_name      1.000   1.000       1.0       0.0
# authors                              1.000   1.000       5.0       0.0
# year                                 1.000   1.000       1.0       0.0
# month                                1.000   1.000       1.0       0.0
# commodity_observed_name              1.000   1.000      32.0       0.0
# category_observed_name               1.000   1.000      32.0       0.0
# ore_unit_observed_name               1.000   1.000      32.0       0.0
# ore_value                            1.000   1.000      32.0       0.0
# grade_unit_observed_name             0.875   0.875      28.0       4.0
# grade_value                          0.875   0.875      28.0       4.0
# cutoff_grade_unit_observed_name      1.000   1.000      32.0       0.0
# cutoff_grade_value                   1.000   1.000      32.0       0.0
# contained_metal                      0.875   0.875      28.0       4.0
# zone                                 1.000   1.000      32.0       0.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               5.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name              32.0
# category_observed_name               32.0
# ore_unit_observed_name               32.0
# ore_value                            32.0
# grade_unit_observed_name             32.0
# grade_value                          32.0
# cutoff_grade_unit_observed_name      32.0
# cutoff_grade_value                   32.0
# contained_metal                      32.0
# zone                                 32.0
#
# Looking at: 02aab13c251f7d11f5bf4a0d752331726ada09d10eac1b32c0b45ae39b0737da38_NI_43-101_Technical_Report_for_the_Hart_Project_in_North_America_dated_February_2010_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['Hart Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
# Extracted:
# {'mining_site_name': ['Hart Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['Glen Cole', ' Andrew Mackenzie', ' Philip Bridson', ' Will Randall'], 'year': [2010], 'month': [2]}
# Extracted:
# {'authors': ['Glen Cole', 'Andrew Mackenzie', 'Philip Bridson', 'Will Randall'], 'year': [2010], 'month': [2]}
#
#
# Mineral Inventory:
# Ground Truth:18
# Extracted:18
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'hart project': 1})
# prediction counter: Counter({'hart project': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2661': 1})
# prediction counter: Counter({'q2661': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'glen cole': 1, 'andrew mackenzie': 1, 'philip bridson': 1, 'will randall': 1})
# prediction counter: Counter({'glen cole': 1, 'andrew mackenzie': 1, 'philip bridson': 1, 'will randall': 1})
#
# Number of tp: 4
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2010': 1})
# prediction counter: Counter({'2010': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'2': 1})
# prediction counter: Counter({'2': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'nickel': 9, 'copper': 9})
# prediction counter: Counter({'nickel': 9, 'copper': 9})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'indicated': 10, 'inferred': 8})
# prediction counter: Counter({'indicated': 10, 'inferred': 8})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 18})
# prediction counter: Counter({'q200': 18})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'120000.0': 2, '12000.0': 2, '999000.0': 2, '228000.0': 2, '353000.0': 2, '59000.0': 2, '60000.0': 2, '22000.0': 2, '14000.0': 2})
# prediction counter: Counter({'120000.0': 2, '999000.0': 2, '353000.0': 2, '60000.0': 2, '14000.0': 2, '12000.0': 2, '228000.0': 2, '59000.0': 2, '22000.0': 2})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 18})
# prediction counter: Counter({'q201': 18})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.1': 6, '0.0': 3, '1.4': 2, '0.5': 2, '0.7': 1, '0.9': 1, '1.6': 1, '1.1': 1, '0.6': 1})
# prediction counter: Counter({'0.1': 6, '0.0': 3, '1.4': 2, '0.5': 2, '0.7': 1, '1.6': 1, '0.6': 1, '0.9': 1, '1.1': 1})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 18})
# prediction counter: Counter({'q201': 18})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.5': 18})
# prediction counter: Counter({'0.5': 18})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'840.0': 1, '103.2': 1, '15584.4': 1, '3192.0': 1, '4800.8': 1, '660.8': 1, '378.0': 1, '114.4': 1, '70.0': 1, '72.0': 1, '8.4': 1, '1098.9': 1, '205.2': 1, '317.7': 1, '47.2': 1, '24.0': 1, '4.4': 1, '4.2': 1})
# prediction counter: Counter({'840.0': 1, '15584.4': 1, '4800.8': 1, '378.0': 1, '70.0': 1, '103.2': 1, '3192.0': 1, '660.8': 1, '114.4': 1, '72.0': 1, '1098.9': 1, '317.7': 1, '24.0': 1, '4.2': 1, '8.4': 1, '205.2': 1, '47.2': 1, '4.4': 1})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'if zone': 4, 'massive zone lower': 4, 'massive zone upper': 4, 'disseminated zone lower': 4, 'disseminated zone upper': 2})
# prediction counter: Counter({'if zone': 4, 'massive zone lower': 4, 'massive zone upper': 4, 'disseminated zone lower': 4, 'disseminated zone upper': 2})
#
# Number of tp: 18
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# report:
#                                   Precision  Recall  TP count  FP count  \
# mining_site_name                       1.0     1.0       1.0       0.0
# country_observed_name                  1.0     1.0       1.0       0.0
# state_or_province_observed_name        1.0     1.0       1.0       0.0
# authors                                1.0     1.0       4.0       0.0
# year                                   1.0     1.0       1.0       0.0
# month                                  1.0     1.0       1.0       0.0
# commodity_observed_name                1.0     1.0      18.0       0.0
# category_observed_name                 1.0     1.0      18.0       0.0
# ore_unit_observed_name                 1.0     1.0      18.0       0.0
# ore_value                              1.0     1.0      18.0       0.0
# grade_unit_observed_name               1.0     1.0      18.0       0.0
# grade_value                            1.0     1.0      18.0       0.0
# cutoff_grade_unit_observed_name        1.0     1.0      18.0       0.0
# cutoff_grade_value                     1.0     1.0      18.0       0.0
# contained_metal                        1.0     1.0      18.0       0.0
# zone                                   1.0     1.0      18.0       0.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               4.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name              18.0
# category_observed_name               18.0
# ore_unit_observed_name               18.0
# ore_value                            18.0
# grade_unit_observed_name             18.0
# grade_value                          18.0
# cutoff_grade_unit_observed_name      18.0
# cutoff_grade_value                   18.0
# contained_metal                      18.0
# zone                                 18.0
#
# Looking at: 02d40055ac23d9034c815a941763045780b709289537ed42a56b7390db074d11cd_NI_43-101_Technical_Report_for_the_McWatters_Project_in_North_America_dated_May_2008_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['McWatters Mine'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
# Extracted:
# {'mining_site_name': ['McWatters Nickel Deposit'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['William Randall'], 'year': [2008], 'month': [5]}
# Extracted:
# {'authors': ['William Randall'], 'year': [2008], 'month': [5]}
#
#
# Mineral Inventory:
# Ground Truth:3
# Extracted:49
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'mcwatters mine': 1})
# prediction counter: Counter({'mcwatters nickel deposit': 1})
#
# Number of tp: 0
#
#
# Number of FP: 1
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2661': 1})
# prediction counter: Counter({'q2661': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'william randall': 1})
# prediction counter: Counter({'william randall': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2008': 1})
# prediction counter: Counter({'2008': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'5': 1})
# prediction counter: Counter({'5': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'nickel': 3})
# prediction counter: Counter({'nickel': 49})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'indicated': 2, 'inferred': 1})
# prediction counter: Counter({'probable': 21, 'proven+probable': 20, 'indicated': 6, 'inferred': 2})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 3})
# prediction counter: Counter({'q200': 49})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'665308.0': 1, '49562.0': 1, '13829.0': 1})
# prediction counter: Counter({'665308.0': 3, '49562.0': 3, '13829.0': 2, '7061.0': 2, '7411.0': 2, '6119.0': 2, '897.0': 2, '1509.0': 2, '5632.0': 2, '2237.0': 2, '15194.0': 2, '239861.0': 2, '46352.0': 2, '13385.0': 2, '38202.0': 2, '9800.0': 2, '56726.0': 2, '12838.0': 2, '12832.0': 2, '8153.0': 2, '11773.0': 2, '2201.0': 2, '98614.0': 2, '596800.0': 1})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 3})
# prediction counter: Counter({'q201': 49})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.7': 1, '3.9': 1, '3.4': 1})
# prediction counter: Counter({'0.6': 12, '0.7': 7, '3.8': 4, '0.8': 4, '0.5': 4, '3.9': 3, '0.9': 3, '3.4': 2, '3.3': 2, '5.5': 2, '3.5': 2, '2.0': 2, '2.7': 2})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 3})
# prediction counter: Counter({'q201': 46, '': 3})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.5': 3})
# prediction counter: Counter({'0.5': 25, '0.6': 21, '0.0': 3})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'4790.2': 1, '1947.8': 1, '468.8': 1})
# prediction counter: Counter({'4790.2': 3, '1947.8': 3, '468.8': 2, '233.0': 2, '406.9': 2, '211.1': 2, '34.1': 2, '30.2': 2, '45.6': 2, '84.3': 2, '410.2': 2, '2086.8': 2, '347.6': 2, '89.7': 2, '221.6': 2, '62.7': 2, '363.0': 2, '87.3': 2, '73.1': 2, '43.2': 2, '62.4': 2, '13.0': 2, '611.4': 2, '5550.2': 1})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'massive zone (lower)': 2, 'disseminated zone (upper)': 1})
# prediction counter: Counter({'massive zone (lower)': 4, 'disseminated zone (upper)': 2, 'panel 1': 2, 'panel 2': 2, 'panel 3': 2, 'panel 4': 2, 'panel 4 (dev)': 2, 'panel 5': 2, 'panel 6': 2, 'panel 7': 2, 'lh 1': 2, 'lh 2 w': 2, 'lh 3': 2, 'lh 4': 2, 'lh 4b': 2, 'lh pr 1': 2, 'lh 2 e': 2, 'lh 1a': 2, 'lh 3 a': 2, 'lh 4a': 2, 'lh 2 w a': 2, 'lh cr': 2, '': 1, 'massive zone ( lower)': 1, 'disseminated zone ( upper )': 1})
#
# Number of tp: 3
#
#
# Number of FP: 46
#
#
# ----------------------------------------------------
# report:
#                                   Precision  Recall  TP count  FP count  \
# mining_site_name                  0.000000     0.0       0.0       1.0
# country_observed_name             1.000000     1.0       1.0       0.0
# state_or_province_observed_name   1.000000     1.0       1.0       0.0
# authors                           1.000000     1.0       1.0       0.0
# year                              1.000000     1.0       1.0       0.0
# month                             1.000000     1.0       1.0       0.0
# commodity_observed_name           0.061224     1.0       3.0      46.0
# category_observed_name            0.061224     1.0       3.0      46.0
# ore_unit_observed_name            0.061224     1.0       3.0      46.0
# ore_value                         0.061224     1.0       3.0      46.0
# grade_unit_observed_name          0.061224     1.0       3.0      46.0
# grade_value                       0.061224     1.0       3.0      46.0
# cutoff_grade_unit_observed_name   0.061224     1.0       3.0      46.0
# cutoff_grade_value                0.061224     1.0       3.0      46.0
# contained_metal                   0.061224     1.0       3.0      46.0
# zone                              0.061224     1.0       3.0      46.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               1.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name               3.0
# category_observed_name                3.0
# ore_unit_observed_name                3.0
# ore_value                             3.0
# grade_unit_observed_name              3.0
# grade_value                           3.0
# cutoff_grade_unit_observed_name       3.0
# cutoff_grade_value                    3.0
# contained_metal                       3.0
# zone                                  3.0
#
# Looking at: 025616a24d90f78dc37e943df3495bce368e062297a2e33a6f519524496c09c443_NI_43-101_Technical_Report_for_the_Los_Santos_Project_in_Europe_Spain_dated_October_2015_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': [''], 'country_observed_name': ['Q1208'], 'state_or_province_observed_name': ['Q5965']}
# Extracted:
# {'mining_site_name': ['Los Santos Project'], 'country_observed_name': ['Q1208'], 'state_or_province_observed_name': ['Q5965']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['Adam Wheeler'], 'year': [2015], 'month': [10]}
# Extracted:
# {'authors': ['Adam Wheeler'], 'year': [2015], 'month': [10]}
#
#
# Mineral Inventory:
# Ground Truth:7
# Extracted:74
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'': 1})
# prediction counter: Counter({'los santos project': 1})
#
# Number of tp: 0
#
#
# Number of FP: 1
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1208': 1})
# prediction counter: Counter({'q1208': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q5965': 1})
# prediction counter: Counter({'q5965': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'adam wheeler': 1})
# prediction counter: Counter({'adam wheeler': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2015': 1})
# prediction counter: Counter({'2015': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'10': 1})
# prediction counter: Counter({'10': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'tungsten': 7})
# prediction counter: Counter({'tungsten': 74})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'measured': 1, 'indicated': 1, 'measured+indicated': 1, 'inferred': 1, 'proven': 1, 'probable': 1, 'proven + probable': 1})
# prediction counter: Counter({'measured+indicated': 26, 'inferred': 13, '': 11, 'indicated': 8, 'proven+probable': 6, 'measured': 4, 'proven': 3, 'probable': 3})
#
# Number of tp: 6
#
#
# Number of FP: 68
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 7})
# prediction counter: Counter({'q200': 74})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'75000.0': 1, '2133000.0': 1, '2208000.0': 1, '1878000.0': 1, '57000.0': 1, '1408000.0': 1, '1465000.0': 1})
# prediction counter: Counter({'57000.0': 3, '1408000.0': 3, '1465000.0': 3, '75000.0': 2, '2133000.0': 2, '1050000.0': 2, '26000.0': 2, '157000.0': 2, '84000.0': 2, '1564000.0': 2, '498000.0': 2, '2062000.0': 2, '1878000.0': 1, '2530000.0': 1, '2410000.0': 1, '2300000.0': 1, '2210000.0': 1, '2110000.0': 1, '2010000.0': 1, '1910000.0': 1, '1820000.0': 1, '1750000.0': 1, '1670000.0': 1, '1600000.0': 1, '1520000.0': 1, '1460000.0': 1, '1400000.0': 1, '1340000.0': 1, '1290000.0': 1, '1240000.0': 1, '1200000.0': 1, '1150000.0': 1, '1000.0': 1, '399000.0': 1, '400000.0': 1, '88000.0': 1, '74000.0': 1, '417000.0': 1, '491000.0': 1, '275000.0': 1, '585000.0': 1, '127000.0': 1, '418000.0': 1, '385000.0': 1, '6717.0': 1, '8130.0': 1, '21885.0': 1, '18455.0': 1, '5.0': 1, '22.0': 1, '76.0': 1, '55289.0': 1, '14000.0': 1, '90000.0': 1, '170000.0': 1, '3000.0': 1, '15000.0': 1, '292000.0': 1, '2208000.0': 1})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 7})
# prediction counter: Counter({'q201': 74})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.3': 4, '0.4': 2, '0.2': 1})
# prediction counter: Counter({'0.3': 27, '0.4': 22, '0.1': 12, '0.2': 9, '0.5': 1, '64.9': 1, '38.0': 1, '17.1': 1})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q201': 7})
# prediction counter: Counter({'q201': 71, '': 3})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.1': 7})
# prediction counter: Counter({'0.1': 63, '0.0': 6, '0.2': 5})
#
# Number of tp: 7
#
#
# Number of FP: 67
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'307.5': 1, '5972.4': 1, '6403.2': 1, '4695.0': 1, '250.8': 1, '4646.4': 1, '4981.0': 1})
# prediction counter: Counter({'250.8': 3, '4646.4': 3, '4981.0': 3, '307.5': 2, '5972.4': 2, '3255.0': 2, '39.0': 2, '219.8': 2, '369.6': 2, '2033.2': 2, '1095.6': 2, '3093.0': 2, '4695.0': 1, '6578.0': 1, '6507.0': 1, '6440.0': 1, '6409.0': 1, '6330.0': 1, '6231.0': 1, '6112.0': 1, '6006.0': 1, '5950.0': 1, '6012.0': 1, '5920.0': 1, '5776.0': 1, '5694.0': 1, '5600.0': 1, '5494.0': 1, '5418.0': 1, '5332.0': 1, '5280.0': 1, '5175.0': 1, '0.6': 1, '877.8': 1, '880.0': 1, '114.4': 1, '303.4': 1, '1251.0': 1, '1571.2': 1, '715.0': 1, '1579.5': 1, '241.3': 1, '627.0': 1, '1386.0': 1, '27.5': 1, '15.4': 1, '94.1': 1, '27.7': 1, '3.2': 1, '8.4': 1, '13.0': 1, '182.5': 1, '28.0': 1, '369.0': 1, '544.0': 1, '6.9': 1, '60.0': 1, '1022.0': 1, '6403.2': 1})
#
# ...
# prediction counter: Counter({'4.9': 3, '0.3': 3, '147.0': 2, '4.6': 2, '18.7': 2, '19.9': 2, '0.0': 2, '0.1': 2, '38424.5': 1, '51717.3': 1, '1453.9': 1, '53332.4': 1, '54116.7': 1, '3137.2': 1, '7368.8': 1, '9241.2': 1, '302.0': 1, '4491.6': 1, '5378.1': 1, '197.0': 1, '39767.6': 1, '25297.0': 1, '57501.8': 1, '34552.0': 1, '2149.6': 1, '1234.0': 1, '12360.2': 1, '5553.0': 1, '37618.0': 1, '20052.5': 1, '142411.0': 1, '79284.5': 1, '5206.7': 1, '3822.4': 1, '21810.8': 1, '3472.0': 1, '87.9': 1, '978.6': 1, '1979.6': 1, '110.9': 1, '1680.1': 1, '348.2': 1, '293.9': 1, '131.6': 1, '6.6': 1, '598.9': 1, '250.7': 1, '370.8': 1, '5243.2': 1, '185.9': 1, '6158.4': 1, '2065.4': 1, '28354.0': 1, '6154.2': 1, '589.1': 1, '440.0': 1, '2113.3': 1, '64.0': 1, '2110.9': 1, '108.7': 1, '603.6': 1, '180.3': 1, '40.1': 1, '269.1': 1, '258.6': 1, '232.2': 1, '6518.5': 1, '255.3': 1, '223.9': 1, '154.1': 1, '1090.5': 1, '45.1': 1, '80.3': 1, '86.2': 1, '14.2': 1, '15.7': 1, '26.7': 1, '11.9': 1, '283.4': 1, '10.2': 1, '559.9': 1, '113.0': 1, '3271.6': 1, '20.5': 1, '19.7': 1, '133.8': 1, '258.5': 1, '8.0': 1, '73.5': 1, '2.2': 1, '12.5': 1, '850.2': 1, '5.1': 1, '3359.1': 1, '1376.9': 1, '13904.4': 1, '1267.6': 1, '79.1': 1, '225.6': 1, '936.3': 1, '37.7': 1, '1033.9': 1, '130.0': 1, '204.7': 1, '37.6': 1, '7.4': 1, '165.8': 1, '119.4': 1, '104.9': 1, '3684.4': 1, '35.7': 1, '14892.1': 1, '3360.1': 1, '62160.7': 1, '6576.7': 1, '219.8': 1, '533.0': 1, '4092.9': 1, '208.2': 1, '4695.7': 1, '320.6': 1, '997.2': 1, '181.7': 1, '370.7': 1, '505.3': 1, '531.9': 1, '15162.6': 1, '242.1': 1, '2458.8': 1, '973.0': 1, '221.7': 1, '52.2': 1, '3642.7': 1, '2066.0': 1, '169.6': 1, '208.8': 1, '91.1': 1, '40.0': 1, '8.4': 1, '2.3': 1, '113.8': 1, '80.0': 1, '5.4': 1, '10.3': 1, '1343.2': 1, '573.2': 1, '93.5': 1, '45.9': 1, '2807.9': 1, '2385.9': 1, '136.6': 1, '170.4': 1, '3.4': 1, '0.4': 1, '5.7': 1, '0.2': 1, '1.9': 1, '5.2': 1})
#
# Number of tp: 118
#
#
# Number of FP: 50
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'massive sulphide domain': 36, 'net textured sulphide domain': 36, 'all domains': 36, 'allammaq': 18, 'hw net': 18, 'puimajuq': 12, 'mesamax': 12, 'mequillon': 12, 'expo': 12, 'ivakkak': 12, 'tk': 12, 'oxidized massive sulphide domain': 12, 'oxidized net textured sulphide domain': 12, 'vein domain': 12, 'underground net textured sulphide resource': 12, 'total net textured sulphide resource': 12, 'hw massive': 12, 'hw vein': 12, 'hw cu': 12, 'fw massive': 12, 'fw net': 12, 'fw vein': 12, 'west ext net': 12, 'open pit net textured sulphide resource': 6, 'west ext vein': 6})
# prediction counter: Counter({'hw net': 18, 'net textured sulphide': 12, 'hw massive': 12, 'hw vein': 12, 'hw cu': 12, 'fw massive': 12, 'fw net': 12, 'fw vein': 12, 'west ext net': 12, 'massive': 12, 'net': 12, '': 12, 'west ext vein': 6, 'mesamax': 3, 'expo': 3, 'ivakkak pit': 3, 'ivakkak underground': 3})
#
# Number of tp: 114
#
#
# Number of FP: 54
#
#
# ----------------------------------------------------
# report:
#                                   Precision    Recall  TP count  FP count  \
# mining_site_name                  1.000000  1.000000       1.0       0.0
# country_observed_name             1.000000  1.000000       1.0       0.0
# state_or_province_observed_name   1.000000  1.000000       1.0       0.0
# authors                           1.000000  1.000000       3.0       0.0
# year                              1.000000  1.000000       1.0       0.0
# month                             1.000000  1.000000       1.0       0.0
# commodity_observed_name           1.000000  0.451613     168.0       0.0
# category_observed_name            0.928571  0.419355     156.0      12.0
# ore_unit_observed_name            1.000000  0.451613     168.0       0.0
# ore_value                         0.678571  0.306452     114.0      54.0
# grade_unit_observed_name          1.000000  0.451613     168.0       0.0
# grade_value                       0.976190  0.440860     164.0       4.0
# cutoff_grade_unit_observed_name   0.214286  0.096774      36.0     132.0
# cutoff_grade_value                0.964286  0.435484     162.0       6.0
# contained_metal                   0.702381  0.317204     118.0      50.0
# zone                              0.678571  0.306452     114.0      54.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               3.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name             372.0
# category_observed_name              372.0
# ore_unit_observed_name              372.0
# ore_value                           372.0
# grade_unit_observed_name            372.0
# grade_value                         372.0
# cutoff_grade_unit_observed_name     372.0
# cutoff_grade_value                  372.0
# contained_metal                     372.0
# zone                                372.0
#
# Looking at: 02fd98e067010f8d853d2c018cb002be462ac7fcd895af4125beb89f42b659f89d_NI_43-101_Technical_Report_for_the_Thunder_Bay_North_Project_in_North_America_dated_March_2011_summary
#
# Locations:
# Ground Truth:
# {'mining_site_name': ['Thunder Bay North Polymetallic Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
# Extracted:
# {'mining_site_name': ['Thunder Bay North Polymetallic Project'], 'country_observed_name': ['Q1038'], 'state_or_province_observed_name': ['Q2661']}
#
#
# Reference:
# Ground Truth:
# {'authors': ['David G. Thomas', ' Jay Melnyk', ' Lynton Gormely', ' Stella Searston', ' Greg Kulla'], 'year': [2011], 'month': [3]}
# Extracted:
# {'authors': ['David G. Thomas', 'Jay Melnyk', 'Lynton Gormely', 'Stella Searston', 'Greg Kulla'], 'year': [2011], 'month': [3]}
#
#
# Mineral Inventory:
# Ground Truth:32
# Extracted:32
#
#
# Key: mining_site_name
# ----------------------------------------------------
# Truth_count = Counter({'thunder bay north polymetallic project': 1})
# prediction counter: Counter({'thunder bay north polymetallic project': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: country_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q1038': 1})
# prediction counter: Counter({'q1038': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: state_or_province_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q2661': 1})
# prediction counter: Counter({'q2661': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: authors
# ----------------------------------------------------
# Truth_count = Counter({'david g. thomas': 1, 'jay melnyk': 1, 'lynton gormely': 1, 'stella searston': 1, 'greg kulla': 1})
# prediction counter: Counter({'david g. thomas': 1, 'jay melnyk': 1, 'lynton gormely': 1, 'stella searston': 1, 'greg kulla': 1})
#
# Number of tp: 5
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: year
# ----------------------------------------------------
# Truth_count = Counter({'2011': 1})
# prediction counter: Counter({'2011': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: month
# ----------------------------------------------------
# Truth_count = Counter({'3': 1})
# prediction counter: Counter({'3': 1})
#
# Number of tp: 1
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: commodity_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'platinum': 4, 'palladium': 4, 'rhodium': 4, 'gold': 4, 'silver': 4, 'copper': 4, 'nickel': 4, 'cobalt': 4})
# prediction counter: Counter({'platinum': 4, 'palladium': 4, 'rhodium': 4, 'gold': 4, 'silver': 4, 'copper': 4, 'nickel': 4, 'cobalt': 4})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: category_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'indicated': 16, 'inferred': 16})
# prediction counter: Counter({'indicated': 16, 'inferred': 16})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q200': 32})
# prediction counter: Counter({'q200': 32})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: ore_value
# ----------------------------------------------------
# Truth_count = Counter({'8460000.0': 8, '53000.0': 8, '1030000.0': 8, '212000.0': 8})
# prediction counter: Counter({'8460000.0': 8, '53000.0': 8, '1030000.0': 8, '212000.0': 8})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q203': 24, 'q201': 8})
# prediction counter: Counter({'q203': 24, 'q201': 8})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.1': 6, '0.2': 6, '1.0': 3, '0.0': 2, '1.5': 2, '1.6': 2, '140.0': 1, '0.9': 1, '142.0': 1, '2.4': 1, '0.4': 1, '172.0': 1, '1.4': 1, '1.3': 1, '1.9': 1, '0.3': 1, '158.0': 1})
# prediction counter: Counter({'0.1': 6, '0.2': 6, '1.0': 3, '0.0': 2, '1.5': 2, '1.6': 2, '0.9': 1, '140.0': 1, '142.0': 1, '2.4': 1, '0.4': 1, '172.0': 1, '1.4': 1, '1.3': 1, '1.9': 1, '0.3': 1, '158.0': 1})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: cutoff_grade_unit_observed_name
# ----------------------------------------------------
# Truth_count = Counter({'q203': 16, '': 16})
# prediction counter: Counter({'q203': 32})
#
# Number of tp: 16
#
#
# Number of FP: 16
#
#
# ----------------------------------------------------
# Key: cutoff_grade_value
# ----------------------------------------------------
# Truth_count = Counter({'0.6': 16, '0.0': 16})
# prediction counter: Counter({'0.6': 16, '1.9': 16})
#
# Number of tp: 16
#
#
# Number of FP: 16
#
#
# ----------------------------------------------------
# Key: contained_metal
# ----------------------------------------------------
# Truth_count = Counter({'87984.0': 1, '82908.0': 1, '3384.0': 1, '5922.0': 1, '126900.0': 1, '21150.0': 1, '15228.0': 1, '11844000.0': 1, '508.8': 1, '471.7': 1, '21.2': 1, '37.1': 1, '848.0': 1, '116.6': 1, '95.4': 1, '75260.0': 1, '16789.0': 1, '15553.0': 1, '824.0': 1, '1133.0': 1, '24720.0': 1, '4017.0': 1, '2472.0': 1, '1771600.0': 1, '2968.0': 1, '2734.8': 1, '127.2': 1, '190.8': 1, '4028.0': 1, '720.8': 1, '487.6': 1, '334960.0': 1})
# prediction counter: Counter({'87984.0': 1, '508.8': 1, '82908.0': 1, '471.7': 1, '3384.0': 1, '21.2': 1, '5922.0': 1, '37.1': 1, '126900.0': 1, '848.0': 1, '21150.0': 1, '116.6': 1, '15228.0': 1, '95.4': 1, '11844000.0': 1, '75260.0': 1, '16789.0': 1, '15553.0': 1, '824.0': 1, '1133.0': 1, '24720.0': 1, '4017.0': 1, '2472.0': 1, '1771600.0': 1, '2968.0': 1, '2734.8': 1, '127.2': 1, '190.8': 1, '4028.0': 1, '720.8': 1, '487.6': 1, '334960.0': 1})
#
# Number of tp: 32
#
#
# Number of FP: 0
#
#
# ----------------------------------------------------
# Key: zone
# ----------------------------------------------------
# Truth_count = Counter({'open pit': 16, 'underground': 16})
# prediction counter: Counter({'': 32})
#
# Number of tp: 0
#
#
# Number of FP: 32
#
#
# ----------------------------------------------------
# report:
#                                   Precision  Recall  TP count  FP count  \
# mining_site_name                       1.0     1.0       1.0       0.0
# country_observed_name                  1.0     1.0       1.0       0.0
# state_or_province_observed_name        1.0     1.0       1.0       0.0
# authors                                1.0     1.0       5.0       0.0
# year                                   1.0     1.0       1.0       0.0
# month                                  1.0     1.0       1.0       0.0
# commodity_observed_name                1.0     1.0      32.0       0.0
# category_observed_name                 1.0     1.0      32.0       0.0
# ore_unit_observed_name                 1.0     1.0      32.0       0.0
# ore_value                              1.0     1.0      32.0       0.0
# grade_unit_observed_name               1.0     1.0      32.0       0.0
# grade_value                            1.0     1.0      32.0       0.0
# cutoff_grade_unit_observed_name        0.5     0.5      16.0      16.0
# cutoff_grade_value                     0.5     0.5      16.0      16.0
# contained_metal                        1.0     1.0      32.0       0.0
# zone                                   0.0     0.0       0.0      32.0
#
#                                  GT count
# mining_site_name                      1.0
# country_observed_name                 1.0
# state_or_province_observed_name       1.0
# authors                               5.0
# year                                  1.0
# month                                 1.0
# commodity_observed_name              32.0
# category_observed_name               32.0
# ore_unit_observed_name               32.0
# ore_value                            32.0
# grade_unit_observed_name             32.0
# grade_value                          32.0
# cutoff_grade_unit_observed_name      32.0
# cutoff_grade_value                   32.0
# contained_metal                      32.0
# zone                                 32.0

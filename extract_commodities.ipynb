# %%
import PyPDF2
import pandas as pd
from tenacity import (
    retry,
    stop_after_attempt,
    wait_random_exponential,
    wait_incrementing,
    wait_fixed,
    wait_exponential
)  # for exponential backoff
import openai
import time
import json
import os
from collections import defaultdict
import warnings
import re
import csv
from datetime import date
from settings import API_KEY
import numpy as np
# Ignore the specific UserWarning from openpyxl
warnings.filterwarnings(action='ignore', category=UserWarning, module='openpyxl')

openai.api_key = API_KEY

@retry(wait=wait_random_exponential(min=1, max=30), stop=stop_after_attempt(16))
def chat_completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %% [markdown]
# ## Update File Name For creating Json File

# %%
pdf_p = "./reports/"
pdf_name = "Mount Pleasant W Mo Bi 9-2012.pdf"
curr_path = pdf_p + pdf_name
primary_commodity = "tungsten"
element_sign = "W"

# %%
def search_text_in_pdf(pdf_path, target_string):
    page_numbers = []
    
    # Open the PDF file in binary mode
    with open(pdf_path, 'rb') as file:
        
        # Create a PDF reader
        pdf = PyPDF2.PdfReader(file)
        
        # Iterate over each page
        for page_num in range(len(pdf.pages)):
            page = pdf.pages[page_num]
            text = page.extract_text()
            text_new = ' '.join(text.replace("\t", " ").split()).lower()
            # Check if target string is in the page's text
            if target_string.lower() in text_new:
                page_numbers.append(page_num)            
    return page_numbers

def get_answ(pdf_path,target_strings,model, content, pr, replace_t = False):
    all_matching_pages = []
    for target_string in target_strings:
        matching_pages = search_text_in_pdf(pdf_path, target_string)
        all_matching_pages += matching_pages
    if len(all_matching_pages)==0:
        return({})

    res = {}
    with open(pdf_path, 'rb') as file:
        pdf = PyPDF2.PdfReader(file)
        all_text = ''
        for matching_page in matching_pages:
            page = pdf.pages[matching_page]
            text = page.extract_text()
            all_text = all_text + '/n' + text
        if replace_t:
            all_text = all_text.replace("\t", " ")

        response = chat_completion_with_backoff(model=model, temperature=0, max_tokens=100, stop='.', messages=[
        {"role": "system", "content": content},
        {"role": "user", "content": pr+all_text},
        ])
        res = json.loads(response['choices'][0]['message']['content'])
        time.sleep(0.1)
    print(f"Here are all matching_pages to search the answer for: {matching_pages}")
    return(res)

# %% [markdown]
# #### Prompt templates

# %%
content = """You are a mining assistant, knowledgable in geology and skilled in 
understanding mining reports. You can extract information about mines, ore and minerals."""

commodity_pr = """You are a geology expert and you are very good in understanding mining reports. You will be given 
a text from a mining report and you have to find out what are the primary commodities and secondary commodities. 
The output should be in the following format: 
{"primary commodities": [primary commodity 1, primary commodity 2], "secondary commodities": [secondary commodity 1, secondary commodity 2]

Note that there could be no primary and secondary commodities mentioned, and in that case you should return None where appropriate.
Here is the text: 
"""
## Deposits
deposit_types_p = "./Deposit classification Scheme.xlsx"
deposit_types = ', '.join(pd.read_excel(deposit_types_p, sheet_name='Deposit classification scheme',engine='openpyxl')['Deposit type'].unique())

deposit_pr = """You are a geology expert and you are very good in understanding mining reports. You will be given 
a text from a mining report and you have to find out what are the deposit types in this mine. You can chose only from 
the provided list of the deposit types. You can chose one or more deposit types. If it is unknown, answer None.
The output should be in the following format: {"deposit types": [deposit type 1, deposit type 2]}

Note that there could be no deposit types mentioned, and in that case you should return None where appropriate.
Here is the list of the provided deposit types: """ + deposit_types + ", None." + """ Here is the text from the report: 
"""
#### TOC
content_toc = "You are a mining assistant, knowledgable in geology and skilled in understanding mining reports. You can extract information about tables of contents from reports."
content_pr = """You are a documentation expert and you can understand very well the table of contents of the mining reports.
You will be provided a table of contents and you need to understand it and return the number and page for each item in a given table of content.
The output should be in the following format: 
{"text":["number", "page"],  "text":["number", "page"]}

For example: 
{"Information Sources and References":["2.5", "7"],
"Reliance on Experts":["3.0", "7"]}

If there are no pages visible or you think there is no table of content in a text, return None.
Here is the text: 
"""
### get header
content_header = """You are a mining assistant, knowledgable in geology and 
skilled in understanding mining reports. You can extract the header of the section from the
given text."""
content_find = """You are a documentation expert and you can understand very well the 
contents of the mining reports. You will be provided a section of a paper and 
you need to understand it and see if in the text the term given is used as a header 
on the given page.
The output should only given as "Yes" or "No". Here is the  
"""
## returning from the tables
response_example = """{'Line1': {'Zone': 'zone', 'Classification': 'classification', 'element Cut-Off': 'cut-off', 'element Tonnage': 
'tonnage', 'element Grade %': 'element % number' }, 'Line2': {'Zone': 'zone', 'Classification': 'classification', 'element Cut-Off': 
'cut-off', 'element Tonnage': 'tonnage', 'element Grade %': 'element % number'},...}"""

table_pr = f"""You are a geology expert and you are very good in understanding mining reports. You will be given 
a text from a mining report and you have to find out what are the different combinations of Zones which is the name of a location,
classification which is either indicated or inferred, cut-off represented as a decimal, tonnage in Tonnes and 
grade given in % from the tables in the text, which will have most of the given headers that include the words
zone, classification or indicated or inferred, cut-off, tonnage, and element %. Please extract the name of the element and place it in the output
below without any additional text. Note we only care about the mineral {primary_commodity} represented by {element_sign}.

For each line in the table create a nested dictionary that follows this json file format as the response:  
{response_example}. 
"""

# %% [markdown]
# ### Get Deposit Types

# %%
deposit_types_p = "./Deposit classification Scheme.xlsx"
deposit_groups = ', '.join(pd.read_excel(deposit_types_p, sheet_name='Deposit classification scheme',engine='openpyxl')['Deposit group'].unique())
deposit_types = ', '.join(pd.read_excel(deposit_types_p, sheet_name='Deposit classification scheme',engine='openpyxl')['Deposit type'].unique())

# %%
print(f"Here are the deposit groups: {deposit_groups} \n\n")
# print(f"Here are the deposit types: {deposit_types}")
# Out:
# Here are the deposit groups: Placer, Laterite, Clay, Supergene, Exotic, Paleochannel, Uranium, Magnesite, Evaporite, Brine, Zeolite, Black shale, Phosphorite, Iron formation, Manganese, Unconformity- related, Collapse breccia pipe, Volcanic-hosted, Sediment-hosted, Mississippi Valley- type (MVT), Non-sulfide, Five-element, Orogenic, Metamorphic, Alkali-calcic, Metasomatic iron, IOCG, IOA, Volcanogenic massive sulfide (VMS), Volcanogenic, Epithermal, Vein, Breccia pipe, Carlin-type, Distal-disseminated, Replacement, Skarn, Porphyry, Greisen, Intrusion-related, Pegmatite, Carbonatite, Peralkaline igneous, Apatite-nepheline- titanite intrusion, Apatite intrusion, Kimberlite, Komatiite, Ultramafic and (or) mafic-layered intrusion, Ultramafic and (or) mafic intrusion, Ultramafic and (or) mafic conduit, Ophiolite, Anorthosite massif, Anorthosite conduit

# %% [markdown]
# ## Get commodities

# %%
target_strings = ["commodit"]
model = 'gpt-3.5-turbo'

all_comodities = {}
res = get_answ(pdf_p + pdf_name,target_strings,model, content, commodity_pr)
print(res)
# Out:
# {}

# %% [markdown]
# ## Get deposit types

# %%
target_strings = ["Deposit type"]
res = get_answ(pdf_p + pdf_name,target_strings,model, content, deposit_pr, replace_t=True)
# Out:
# Here are all matching_pages to search the answer for: [2, 53, 55, 59]

# %%
idx = 0
deposit_types = {}
deposit_types['deposit types'] = []
for dep in res['deposit types']:
    deposit_types['deposit types'].append({"id": idx, "name": dep})
    idx +=1
print(deposit_types)
# Out:
# {'deposit types': [{'id': 0, 'name': 'Porphyry tin-(±indium) deposits'}, {'id': 1, 'name': 'Tungsten-molybdenum deposits'}]}

# %% [markdown]
# ## Get TOC
#
# old content_pr:
# content_pr = """You are a documentation expert and you can understand very well the table of contents of the mining reports.
# You will be provided a table of contents and you need to understand it and return the number and page for each item in a given table of content.
# The output should be in the following format:
# {["number", "text", "page"],
# ["number", "text", "page"]}
#
# For example:
# {["2.5", "Information Sources and References", "7"],
# ["3.0", "Reliance on Experts", "7"]}
#
# If there are no pages visible or you think there is no table of content in a text, return None.
# Here is the text
#
# #### Overall Steps
# 1. Get the table of contents
# 2. From the table of contents dictionary, look for Mineral Resource or whichever term you need.
# 3. Create the term header and from the given start page look for where we have the term header to get the offset
# 4. With the offset, find where the tables are starting from that page to maybe the next section(?) or last page we see that table
#
# Notes: need to determine how to stop duplicates being added. Need to determine best way to create a search term
# within the document. Need to figure out best extraction method before adding to the csv.
#
# - Should also think about best way to search for the header: i think we can get the term section number and then the term from the TOC. Can use this to search for the start page. Do not need to do chat GPT. Problems with current. If pages are not always identical or if there is a spacing problem. Should try doing a cosine or fix the paper to dismiss spacing issues.

# %%
def is_json_compatible(string):
    try:
        json.loads(string)
        return True
    except ValueError:
        return False

def get_toc(file_path):
    with open(file_path, 'rb') as file:
        pdf = PyPDF2.PdfReader(file)

        # scan first n=8 pages and get the TOC
        all_res = {}
        for i in range(0,8):
            print(f"on page {i}")
            page = pdf.pages[i]
            text = page.extract_text()
            model = 'gpt-4'
            response = chat_completion_with_backoff(model=model, temperature=0, max_tokens=2000, stop='', messages=[
                {"role": "system", "content": content_toc},
                {"role": "user", "content": content_pr + text},
                ])
            res = response['choices'][0]['message']['content']
            # print(res)
            if is_json_compatible(res):
                ans = json.loads(res)
                for key in ans.keys():
                    all_res[key] = ans[key]
    return all_res

# %%
all_res = get_toc(curr_path)
print(all_res)
# Out:
# on page 0
# on page 1
# on page 2
# on page 3
# on page 4
# on page 5
# on page 6
# on page 7
# {'SUMMARY': ['1', '1'], 'INTRODUCTION AND TERMS OF REFERENCE': ['2', '7'], 'INTRODUCTION': ['2.1', '7'], 'TERMS OF REFERENCE': ['2.2', '8'], 'SOURCES OF INFORMATION': ['2.3', '9'], 'UNITS AND CURRENCY': ['2.4', '9'], 'DISCLAIMER': ['2.5', '10'], 'RELIANCE ON OTHER EXPERTS': ['3', '11'], 'PROPERTY DESCRIPTION AND LOCATION': ['4', '12'], 'GENERAL': ['9.1', '52'], 'SURFACE RIGHTS': ['4.2', '15'], 'ROYALTY PAYMENTS': ['4.3', '16'], 'MINE/MILL BUILDING AND EQUIPMENT OWNERSHIP': ['4.4', '16'], 'ACCESS, CLIMATE, LOCAL RESOURCES, INFRASTRUCTURE AND PHYSIOGRAPHY': ['5', '17'], 'ACCESS': ['5.1', '17'], 'CLIMATE': ['5.2', '17'], 'LOCAL RESOURCES AND INFRASTRUCTURE': ['5.3', '18'], 'PHYSIOGRAPHY': ['5.4', '19'], 'HISTORY': ['6', '21'], 'EXPLORATION AND DEVELOPMENT': ['6.2', '21'], 'MINING/MILLING OPERATIONS': ['6.3', '31'], 'HISTORICAL DIAMOND DRILLING': ['6.4', '33'], 'HISTORICAL MINERAL RESOURCE AND MINERAL RESERVE ESTIMATES': ['6.5', '37'], 'GEOLOGICAL SETTING': ['7', '38'], 'REGIONAL GEOLOGY': ['7.1', '38'], 'LOCAL GEOLOGY': ['7.2', '40'], 'DEPOSIT TYPES': ['8', '47'], 'PORPHYRY MOLYBDENUM-(±TUNGSTEN) DEPOSITS': ['8.2', '48'], 'PORPHYRY TIN-(±INDIUM) DEPOSITS': ['8.3', '49'], 'MINERALIZATION': ['9', '52'], 'FIRE TOWER ZONE': ['9.2', '52'], 'SCOTIA ZONE': ['9.3', '56'], 'SADDLE ZONE': ['9.4', '56'], 'NORTH ZONE': ['9.5', '57'], 'HORNET HILL': ['9.6', '62'], 'URANIUM AND GOLD MINERALIZATION, MOUNT PLEASANT REGION': ['9.7', '63'], 'EXPLORATION': ['10', '64'], 'RE-SAMPLING OF TUNGSTEN-MOLYBDENUM ORES': ['10.1', '66'], 'RE-ANALYSES OF SULPHIDE CONCENTRATE POND PULPS': ['10.2', '66'], 'ADDITIONAL CORE SAMPLING OF 1995 HISTORICAL DRILL CORE': ['10.3', '66'], 'DUPLICATE ANALYSES OF 2006 PULP SAMPLES': ['10.4', '68'], 'DRILLING': ['11', '71'], 'PHASE 1 DRILL PROGRAM': ['11.1', '71'], 'SAMPLING METHOD AND APPROACH': ['12', '76'], 'SAMPLE PREPARATION, ANALYSES AND SECURITY': ['13', '78'], 'DATA CORROBORATION': ['14', '81'], 'ADJACENT PROPERTIES': ['15', '84'], 'MINERAL PROCESSING AND METALLURGICAL TESTING': ['16', '85'], 'GRAVITY-FLOTATION BENCH TESTING': ['16.1', '85'], 'HYDROMET TESTING': ['16.2', '85'], 'HIGH-DEFINITION MINERALOGY ASSESSMENT': ['16.3', '86'], 'MINERAL RESOURCE AND MINERAL RESERVE ESTIMATES': ['17', '88'], 'SRK MINERAL RESOURCE ESTIMATE STATEMENT': ['17.1', '88'], 'GENERAL MINERAL RESOURCE ESTIMATION METHODOLOGY': ['17.2', '89'], 'DATABASE': ['17.3', '90'], 'RESOURCE MODELLING PROCEDURES': ['17.4', '91'], 'DATABASE PREPARATION, STATISTICAL ANALYSIS AND COMPOSITING': ['17.5', '94'], 'VARIOGRAPHY': ['17.6', '103'], 'RESOURCE ESTIMATION': ['17.7', '103'], 'MINERAL RESOURCE CLASSIFICATION AND TABULATION': ['17.8', '107'], 'OTHER RELEVANT DATA AND INFORMATION': ['18', '111'], 'INTERPRETATION AND CONCLUSIONS': ['19', '113'], 'RECOMMENDATIONS': ['20', '116'], 'CERTIFICATES': ['', '118'], 'REFERENCES': ['', '122'], 'APPENDICES': ['', '128'], 'Mount Pleasant property claims': ['1', '12'], 'History of work on the Mount Pleasant property': ['2', '22'], 'Summary of Mount Pleasant drill programs – surface and underground': ['3', '34'], 'Summary of Inferred Mineral Resource estimate': ['4', '37'], 'Comparative analyses of 1995 Piskehegan pulp samples': ['5', '70'], 'Phase 1 diamond drillholes on the Fire Tower Zone': ['6', '72'], 'Summary results of the 2008 diamond drill program': ['7', '73'], 'Comparison of 2008 twin hole assay results': ['8', '73'], 'Phase II drill core assay results for the FTN and FTE sub-zones': ['9', '74'], 'Phase II drill core assay results - Fire Tower breccia zone': ['10', '75'], 'Split core samples collected by WGM': ['11', '82'], 'WGM analytical results (Mount Pleasant)': ['12', '82'], 'Adex check pulps and rejects for 2008 FTZ Phase I diamond drilling program': ['13', '83'], 'Mt. Pleasant Mineral Resource Estimate, Fire Tower Zone (SRK, October 11, 2008)': ['14', '88'], 'Basic statistics of drillhole samples in FTZ': ['15', '97'], 'Basic statistics of 3.0 m composites in the mineralized envolope of the FT zone' ...

# %% [markdown]
# ## Section to Search or Filter the document for the Mineral Resource Header
# Note: We are assuming that the report uses the NUMBER SECTION + TITLE in the report to refer to the start of a new section

# %%
## Need to get offset 
def get_offset(term, start_page, curr_file):
        ## need to look for term 
        # print(start_page)
        with open(curr_file, 'rb') as file:
            pdf = PyPDF2.PdfReader(file)
            
            for i in range(start_page-1, start_page + 10):
                # print(f"On page {i}")
                page = pdf.pages[i]
                text = page.extract_text()
                text_new = ' '.join(text.replace("\t", " ").split()).lower()
                model = 'gpt-4'
                response = chat_completion_with_backoff(model=model, temperature=0, max_tokens=2000, stop='', messages=[
                    {"role": "system", "content": content_header},
                    {"role": "user", "content": content_find+f"Term: {term} and here is the text" + text_new},
                    ])
                # print(text)
                res = response['choices'][0]['message']['content']
                if res == "Yes":
                    # print(text)
                    return (start_page, i, i-start_page)
            return (start_page,None, None)
    
def is_int(value):
    try:
        int(value)
        return True
    except ValueError:
        return False
    
def find_header_pg(pdf_path, target_string):
    
    # Open the PDF file in binary mode
    with open(pdf_path, 'rb') as file:
        
        # Create a PDF reader
        pdf = PyPDF2.PdfReader(file)
        
        # Iterate over each page
        for page_num in range(7, len(pdf.pages)):
            page = pdf.pages[page_num]
            text = page.extract_text()
            text_new = ' '.join(text.replace("\t", " ").split()).lower()
            # Check if target string is in the page's text
            if target_string.lower() in text_new:
                return page_num
        return 0
            
def get_correct_pages(term_list, curr_path, use_section=True):
    correct_pages = {}
    
    for inner_dict in term_list:
        for title in inner_dict:
            if use_section:
                header_term = inner_dict[title][0] + " " + title
                new_pg = find_header_pg(curr_path, header_term)
            else:
                new_pg = find_header_pg(curr_path, title)
            correct_pages[title] = new_pg
    return correct_pages

# %%
mineral_res = []
for key in all_res.keys():
    if "mineral resource" in key.lower():
        mineral_res.append({key.lower(): all_res[key]})

print(mineral_res)
# Out:
# [{'historical mineral resource and mineral reserve estimates': ['6.5', '37']}, {'mineral resource and mineral reserve estimates': ['17', '88']}, {'srk mineral resource estimate statement': ['17.1', '88']}, {'general mineral resource estimation methodology': ['17.2', '89']}, {'mineral resource classification and tabulation': ['17.8', '107']}, {'summary of inferred mineral resource estimate': ['4', '37']}, {'mt. pleasant mineral resource estimate, fire tower zone (srk, october 11, 2008)': ['14', '88']}, {'mt. pleasant mineral resource statement, fire tower zone (srk, october 11, 2008)': ['21', '107']}, {'ftz indicated mineral resources grade sensitivities': ['23', '108']}, {'ftz inferred mineral resources grade sensitivities': ['24', '109']}, {'the mineral resource estimated using id2 methods': ['25', '110']}]

# %%
term = list(mineral_res[0].keys())[0]
section = mineral_res[0][term][0]
header_term = section + " " + term
og_pg =  mineral_res[0][term][1]

if is_int(og_pg):
    print("Using Chat GPT to Find OFFSET")
    og_pg = int(og_pg)
    ## Note need to use header_term to find correct section
    og_pg, new_pg, offset = get_offset(header_term, og_pg, curr_path)
    print(f"Found the offset: {offset}")

    correct_pages = {}
    if offset != None:
        for inner_dict in mineral_res:
            for title in inner_dict:
                old_pg = inner_dict[title][1]
                new_pg = int(old_pg) + offset
                correct_pages[title] = new_pg
    else:
        print("Using String Matching to Find OFFSET")
        correct_pages = get_correct_pages(mineral_res, )
else:
    print("Using String Matching to Find OFFSET")
    correct_pages = get_correct_pages(mineral_res, curr_path)
    
## trying to see if there were missing values
for key in correct_pages:
    if correct_pages[key] == 0:
        # try updating any keys that weren't updated
        addn_dict = get_correct_pages(mineral_res, curr_path, use_section = False)
        for key in addn_dict:
            correct_pages[key] = addn_dict[key]
            
print(correct_pages)
# Out:
# Using Chat GPT to Find OFFSET
# Found the offset: 6
# {'historical mineral resource and mineral reserve estimates': 43, 'mineral resource and mineral reserve estimates': 94, 'srk mineral resource estimate statement': 94, 'general mineral resource estimation methodology': 95, 'mineral resource classification and tabulation': 113, 'summary of inferred mineral resource estimate': 43, 'mt. pleasant mineral resource estimate, fire tower zone (srk, october 11, 2008)': 94, 'mt. pleasant mineral resource statement, fire tower zone (srk, october 11, 2008)': 113, 'ftz indicated mineral resources grade sensitivities': 114, 'ftz inferred mineral resources grade sensitivities': 115, 'the mineral resource estimated using id2 methods': 116}

# %% [markdown]
# ## Searching within the table:
# - Classification (Indicated, Inferred...)
# - Cut-off
# - Tonnage
# - Grade
#
# ### always look in mineral resource
# - look at the page number offsets
# - compare to the TOC
# - Find summary and the do the offset

# %% [markdown]
# ## Use Chat GPT to search for the table

# %%
def search_for_tables(pdf_path, start_page):
    uniq_dict = {}
    for page_num in range(start_page, start_page+4):
        with open(pdf_path, 'rb') as file:
            pdf = PyPDF2.PdfReader(file)
            page = pdf.pages[page_num]
            text = page.extract_text()
            model = 'gpt-4'
            #model = 'gpt-3.5-turbo'
            response = chat_completion_with_backoff(model=model, temperature=0, max_tokens=2000, stop='', messages=[
                {"role": "system", "content": content},
                {"role": "user", "content": table_pr + text},
                ])
            res = response['choices'][0]['message']['content']
            match = re.search(r'\{.*\}', res, re.DOTALL)
            if match:
                extracted_content = match.group(0).replace("'", '"')
                # print(extracted_content)
                if is_json_compatible(extracted_content):
                    ans = json.loads(extracted_content)
                    for inner_dict in ans.values():
                        inner_dict['page_num']= page_num + 1
                        if tuple(inner_dict.values()) in uniq_dict.keys():
                            pass
                        else:
                            uniq_dict[tuple(inner_dict.values())] = "seen"
                    
            # else:
            #     print("No match found.") 
    return uniq_dict

# %%
overall_dict = {}
for header in correct_pages:
    temp = search_for_tables(curr_path, correct_pages[header])
    print(f"\n Here is the dictionary from header {header}: \n {temp}\n")
    for key in temp:
        if key in overall_dict:
            pass
        else:
            overall_dict[key] = 'seen'
# Out:
#  Here is the dictionary from header historical mineral resource and mineral reserve estimates:
#  {('Fire Tower West', 'Inferred', '0.3', '9,209,081', '0.34', 44): 'seen', ('Fire Tower North', 'Inferred', '0.3', '3,865,356', '0.37', 44): 'seen'}
#
#
#  Here is the dictionary from header mineral resource and mineral reserve estimates:
#  {('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 95): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 95): 'seen', ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 95): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 95): 'seen'}
#
#
#  Here is the dictionary from header srk mineral resource estimate statement:
#  {('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 95): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 95): 'seen', ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 95): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 95): 'seen'}
#
#
#  Here is the dictionary from header general mineral resource estimation methodology:
#  {}
#
#
#  Here is the dictionary from header mineral resource classification and tabulation:
#  {('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 114): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 114): 'seen', ('Total Indicated', 'Indicated', '0.3', '13,489,000', '0.33', 114): 'seen', ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 114): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 114): 'seen', ('Total Inferred', 'Inferred', '0.3', '841,700', '0.26', 114): 'seen', ('West Zone', 'Indicated', '0.0', '9,391,828', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.1', '9,335,719', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.2', '9,281,108', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.3', '9,148,912', '0.32', 115): 'seen', ('West Zone', 'Indicated', '0.4', '8,487,233', '0.33', 115): 'seen', ('West Zone', 'Indicated', '0.5', '6,552,197', '0.36', 115): 'seen', ('West Zone', 'Indicated', '0.6', '4,362,858', '0.41', 115): 'seen', ('West Zone', 'Indicated', '0.7', '2,669,859', '0.47', 115): 'seen', ('West Zone', 'Indicated', '0.8', '1,566,478', '0.54', 115): 'seen', ('West Zone', 'Indicated', '0.9', '885,926', '0.61', 115): 'seen', ('West Zone', 'Indicated', '1.0', '473,516', '0.67', 115): 'seen', ('North Zone', 'Indicated', '0.0', '4,473,814', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.1', '4,473,097', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.2', '4,459,377', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.3', '4,340,129', '0.35', 115): 'seen', ('North Zone', 'Indicated', '0.4', '3,753,591', '0.38', 115): 'seen', ('North Zone', 'Indicated', '0.5', '2,843,273', '0.43', 115): 'seen', ('North Zone', 'Indicated', '0.6', '2,112,474', '0.48', 115): 'seen', ('North Zone', 'Indicated', '0.7', '1,508,729', '0.54', 115): 'seen', ('North Zone', 'Indicated', '0.8', '993,335', '0.60', 115): 'seen', ('North Zone', 'Indicated', '0.9', '652,196', '0.66', 115): 'seen', ('North Zone', 'Indicated', '1.0', '418,329', '0.72', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.0', '13,865,642', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.1', '13,808,816', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.2', '13,740,485', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.3', '13,489,041', '0.33', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.4', '12,240,824', '0.34', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.5', '9,395,470', '0.38', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.6', '6,475,333', '0.43', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.7', '4,178,588', '0.50', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.8', '2,559,813', '0.56', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.9', '1,538,122', '0.63', 115): 'seen', ('Total West and North Zones', 'Indicated', '1.0', '891,845', '0.70', 115): 'seen', ('West Zone', 'Inferred', '0.0', '964,206', '0.23', 116): 'seen', ('West Zone', 'Inferred', '0.1', '954,238', '0.24', 116): 'seen', ('West Zone', 'Inferred', '0.2', '894,044', '0.25', 116): 'seen', ('West Zone', 'Inferred', '0.3', '831,012', '0.26', 116): 'seen', ('West Zone', 'Inferred', '0.4', '699,164', '0.28', 116): 'seen', ('West Zone', 'Inferred', '0.5', '464,852', '0.32', 116): 'seen', ('West Zone', 'Inferred', '0.6', '264,611', '0.39', 116): 'seen', ('West Zone', 'Inferred', '0.7', '138,317', '0.46', 116): 'seen', ('West Zone', 'Inferred', '0.8', '73,221', '0.53', 116): 'seen', ('West Zone', 'Inferred', '0.9', '30,351', '0.63', 116): 'seen', ('West Zone', 'Inferred', '1.0', '18,349', '0.72', 116): 'seen', ('North Zone', 'Inferred', '0.0', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.1', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.2', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.3', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.4', '8,822', '0.28', 116): 'seen', ('North Zone', 'Inferred', '0.5', '5 ...
#
#
#  Here is the dictionary from header summary of inferred mineral resource estimate:
#  {('Fire Tower West', 'Inferred', '0.3', '9,209,081', '0.34', 44): 'seen', ('Fire Tower North', 'Inferred', '0.3', '3,865,356', '0.37', 44): 'seen', ('Total Fire Tower Zone', 'Inferred', '0.3', '13,074,438', '0.35', 44): 'seen'}
#
#
#  Here is the dictionary from header mt. pleasant mineral resource estimate, fire tower zone (srk, october 11, 2008):
#  {('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 95): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 95): 'seen', ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 95): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 95): 'seen'}
#
#
#  Here is the dictionary from header mt. pleasant mineral resource statement, fire tower zone (srk, october 11, 2008):
#  {('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 114): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 114): 'seen', ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 114): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 114): 'seen', ('West Zone', 'Indicated', '0.0', '9,391,828', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.1', '9,335,719', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.2', '9,281,108', '0.31', 115): 'seen', ('West Zone', 'Indicated', '0.3', '9,148,912', '0.32', 115): 'seen', ('West Zone', 'Indicated', '0.4', '8,487,233', '0.33', 115): 'seen', ('West Zone', 'Indicated', '0.5', '6,552,197', '0.36', 115): 'seen', ('West Zone', 'Indicated', '0.6', '4,362,858', '0.41', 115): 'seen', ('West Zone', 'Indicated', '0.7', '2,669,859', '0.47', 115): 'seen', ('West Zone', 'Indicated', '0.8', '1,566,478', '0.54', 115): 'seen', ('West Zone', 'Indicated', '0.9', '885,926', '0.61', 115): 'seen', ('West Zone', 'Indicated', '1.0', '473,516', '0.67', 115): 'seen', ('North Zone', 'Indicated', '0.0', '4,473,814', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.1', '4,473,097', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.2', '4,459,377', '0.34', 115): 'seen', ('North Zone', 'Indicated', '0.3', '4,340,129', '0.35', 115): 'seen', ('North Zone', 'Indicated', '0.4', '3,753,591', '0.38', 115): 'seen', ('North Zone', 'Indicated', '0.5', '2,843,273', '0.43', 115): 'seen', ('North Zone', 'Indicated', '0.6', '2,112,474', '0.48', 115): 'seen', ('North Zone', 'Indicated', '0.7', '1,508,729', '0.54', 115): 'seen', ('North Zone', 'Indicated', '0.8', '993,335', '0.60', 115): 'seen', ('North Zone', 'Indicated', '0.9', '652,196', '0.66', 115): 'seen', ('North Zone', 'Indicated', '1.0', '418,329', '0.72', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.0', '13,865,642', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.1', '13,808,816', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.2', '13,740,485', '0.32', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.3', '13,489,041', '0.33', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.4', '12,240,824', '0.34', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.5', '9,395,470', '0.38', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.6', '6,475,333', '0.43', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.7', '4,178,588', '0.50', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.8', '2,559,813', '0.56', 115): 'seen', ('Total West and North Zones', 'Indicated', '0.9', '1,538,122', '0.63', 115): 'seen', ('Total West and North Zones', 'Indicated', '1.0', '891,845', '0.70', 115): 'seen', ('West Zone', 'Inferred', '0.0', '964,206', '0.23', 116): 'seen', ('West Zone', 'Inferred', '0.1', '954,238', '0.24', 116): 'seen', ('West Zone', 'Inferred', '0.2', '894,044', '0.25', 116): 'seen', ('West Zone', 'Inferred', '0.3', '831,012', '0.26', 116): 'seen', ('West Zone', 'Inferred', '0.4', '699,164', '0.28', 116): 'seen', ('West Zone', 'Inferred', '0.5', '464,852', '0.32', 116): 'seen', ('West Zone', 'Inferred', '0.6', '264,611', '0.39', 116): 'seen', ('West Zone', 'Inferred', '0.7', '138,317', '0.46', 116): 'seen', ('West Zone', 'Inferred', '0.8', '73,221', '0.53', 116): 'seen', ('West Zone', 'Inferred', '0.9', '30,351', '0.63', 116): 'seen', ('West Zone', 'Inferred', '1.0', '18,349', '0.72', 116): 'seen', ('North Zone', 'Inferred', '0.0', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.1', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.2', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.3', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.4', '8,822', '0.28', 116): 'seen', ('North Zone', 'Inferred', '0.5', '5,599', '0.32', 116): 'seen', ('North Zone', 'Inferred', '0.6', '2,007', '0.39', 116): 'seen', ('North Zone', 'Inferred', '0.7', '391', '0.57', 116) ...
#
#
#  Here is the dictionary from header ftz indicated mineral resources grade sensitivities:
#  {('West Zone Indicated', 'Indicated', '0.0', '9,391,828', '0.31', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.1', '9,335,719', '0.31', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.2', '9,281,108', '0.31', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.3', '9,148,912', '0.32', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.4', '8,487,233', '0.33', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.5', '6,552,197', '0.36', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.6', '4,362,858', '0.41', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.7', '2,669,859', '0.47', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.8', '1,566,478', '0.54', 115): 'seen', ('West Zone Indicated', 'Indicated', '0.9', '885,926', '0.61', 115): 'seen', ('West Zone Indicated', 'Indicated', '1.0', '473,516', '0.67', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.0', '4,473,814', '0.34', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.1', '4,473,097', '0.34', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.2', '4,459,377', '0.34', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.3', '4,340,129', '0.35', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.4', '3,753,591', '0.38', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.5', '2,843,273', '0.43', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.6', '2,112,474', '0.48', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.7', '1,508,729', '0.54', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.8', '993,335', '0.60', 115): 'seen', ('North Zone Indicated', 'Indicated', '0.9', '652,196', '0.66', 115): 'seen', ('North Zone Indicated', 'Indicated', '1.0', '418,329', '0.72', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.0', '13,865,642', '0.32', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.1', '13,808,816', '0.32', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.2', '13,740,485', '0.32', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.3', '13,489,041', '0.33', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.4', '12,240,824', '0.34', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.5', '9,395,470', '0.38', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.6', '6,475,333', '0.43', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.7', '4,178,588', '0.50', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.8', '2,559,813', '0.56', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '0.9', '1,538,122', '0.63', 115): 'seen', ('Total West and North Zones Indicated', 'Indicated', '1.0', '891,845', '0.70', 115): 'seen', ('West Zone', 'Inferred', '0.0', '964,206', '0.23', 116): 'seen', ('West Zone', 'Inferred', '0.1', '954,238', '0.24', 116): 'seen', ('West Zone', 'Inferred', '0.2', '894,044', '0.25', 116): 'seen', ('West Zone', 'Inferred', '0.3', '831,012', '0.26', 116): 'seen', ('West Zone', 'Inferred', '0.4', '699,164', '0.28', 116): 'seen', ('West Zone', 'Inferred', '0.5', '464,852', '0.32', 116): 'seen', ('West Zone', 'Inferred', '0.6', '264,611', '0.39', 116): 'seen', ('West Zone', 'Inferred', '0.7', '138,317', '0.46', 116): 'seen', ('West Zone', 'Inferred', '0.8', '73,221', '0.53', 116): 'seen', ('West Zone', 'Inferred', '0.9', '30,351', '0.63', 116): 'seen', ('West Zone', 'Inferred', '1.0', '18,349', '0.72', 116): 'seen', ('North Zone', 'Inferred', '0.0', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.1', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.2', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.3', '10,745', '0.26', 116): 'seen', ('North Zone', 'Inferred', '0.4', '8,822', '0.28', 116): 'seen', ('North Zone', 'Inferred', '0.5', '5,599', '0.32', 116): 'seen', ('North Zone', 'Inferred', '0.6', '2,007', '0.39', 116): 'seen', ('North Zone', 'In ...
#
#
#  Here is the dictionary from header ftz inferred mineral resources grade sensitivities:
#  {('West Zone', 'Inferred', 0.0, 964206, 0.23, 116): 'seen', ('West Zone', 'Inferred', 0.1, 954238, 0.24, 116): 'seen', ('West Zone', 'Inferred', 0.2, 894044, 0.25, 116): 'seen', ('West Zone', 'Inferred', 0.3, 831012, 0.26, 116): 'seen', ('West Zone', 'Inferred', 0.4, 699164, 0.28, 116): 'seen', ('West Zone', 'Inferred', 0.5, 464852, 0.32, 116): 'seen', ('West Zone', 'Inferred', 0.6, 264611, 0.39, 116): 'seen', ('West Zone', 'Inferred', 0.7, 138317, 0.46, 116): 'seen', ('West Zone', 'Inferred', 0.8, 73221, 0.53, 116): 'seen', ('West Zone', 'Inferred', 0.9, 30351, 0.63, 116): 'seen', ('West Zone', 'Inferred', 1.0, 18349, 0.72, 116): 'seen', ('North Zone', 'Inferred', 0.0, 10745, 0.26, 116): 'seen', ('North Zone', 'Inferred', 0.1, 10745, 0.26, 116): 'seen', ('North Zone', 'Inferred', 0.2, 10745, 0.26, 116): 'seen', ('North Zone', 'Inferred', 0.3, 10745, 0.26, 116): 'seen', ('North Zone', 'Inferred', 0.4, 8822, 0.28, 116): 'seen', ('North Zone', 'Inferred', 0.5, 5599, 0.32, 116): 'seen', ('North Zone', 'Inferred', 0.6, 2007, 0.39, 116): 'seen', ('North Zone', 'Inferred', 0.7, 391, 0.57, 116): 'seen', ('North Zone', 'Inferred', 0.8, 391, 0.57, 116): 'seen', ('North Zone', 'Inferred', 0.9, 109, 0.73, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.0, 974951, 0.23, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.1, 964983, 0.24, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.2, 904789, 0.25, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.3, 841757, 0.26, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.4, 707986, 0.28, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.5, 470451, 0.32, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.6, 266618, 0.39, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.7, 138708, 0.46, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.8, 73612, 0.53, 116): 'seen', ('Total West and North Zones', 'Inferred', 0.9, 30460, 0.63, 116): 'seen', ('Total West and North Zones', 'Inferred', 1.0, 18349, 0.72, 116): 'seen', ('Fire Tower West', 'Indicated', '0.3', '9,110,400', '0.32', 117): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,321,900', '0.35', 117): 'seen', ('Fire Tower West', 'Inferred', '0.3', '813,000', '0.26', 117): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 117): 'seen'}
#
#
#  Here is the dictionary from header the mineral resource estimated using id2 methods:
#  {('Fire Tower West', 'Indicated', '0.3', '9,110,400', '0.32', 117): 'seen', ('Fire Tower North', 'Indicated', '0.3', '4,321,900', '0.35', 117): 'seen', ('Total Indicated', 'Indicated', '0.3', '13,432,300', '0.33', 117): 'seen', ('Fire Tower West', 'Inferred', '0.3', '813,000', '0.26', 117): 'seen', ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 117): 'seen', ('Total Inferred', 'Inferred', '0.3', '823,700', '0.26', 117): 'seen'}

# %%
overall_dict
# Out:
# {('Fire Tower West', 'Inferred', '0.3', '9,209,081', '0.34', 44): 'seen',
#  ('Fire Tower North', 'Inferred', '0.3', '3,865,356', '0.37', 44): 'seen',
#  ('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 95): 'seen',
#  ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 95): 'seen',
#  ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 95): 'seen',
#  ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 95): 'seen',
#  ('Fire Tower West', 'Indicated', '0.3', '9,148,900', '0.32', 114): 'seen',
#  ('Fire Tower North', 'Indicated', '0.3', '4,340,100', '0.35', 114): 'seen',
#  ('Total Indicated', 'Indicated', '0.3', '13,489,000', '0.33', 114): 'seen',
#  ('Fire Tower West', 'Inferred', '0.3', '831,000', '0.26', 114): 'seen',
#  ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 114): 'seen',
#  ('Total Inferred', 'Inferred', '0.3', '841,700', '0.26', 114): 'seen',
#  ('West Zone', 'Indicated', '0.0', '9,391,828', '0.31', 115): 'seen',
#  ('West Zone', 'Indicated', '0.1', '9,335,719', '0.31', 115): 'seen',
#  ('West Zone', 'Indicated', '0.2', '9,281,108', '0.31', 115): 'seen',
#  ('West Zone', 'Indicated', '0.3', '9,148,912', '0.32', 115): 'seen',
#  ('West Zone', 'Indicated', '0.4', '8,487,233', '0.33', 115): 'seen',
#  ('West Zone', 'Indicated', '0.5', '6,552,197', '0.36', 115): 'seen',
#  ('West Zone', 'Indicated', '0.6', '4,362,858', '0.41', 115): 'seen',
#  ('West Zone', 'Indicated', '0.7', '2,669,859', '0.47', 115): 'seen',
#  ('West Zone', 'Indicated', '0.8', '1,566,478', '0.54', 115): 'seen',
#  ('West Zone', 'Indicated', '0.9', '885,926', '0.61', 115): 'seen',
#  ('West Zone', 'Indicated', '1.0', '473,516', '0.67', 115): 'seen',
#  ('North Zone', 'Indicated', '0.0', '4,473,814', '0.34', 115): 'seen',
#  ('North Zone', 'Indicated', '0.1', '4,473,097', '0.34', 115): 'seen',
#  ('North Zone', 'Indicated', '0.2', '4,459,377', '0.34', 115): 'seen',
#  ('North Zone', 'Indicated', '0.3', '4,340,129', '0.35', 115): 'seen',
#  ('North Zone', 'Indicated', '0.4', '3,753,591', '0.38', 115): 'seen',
#  ('North Zone', 'Indicated', '0.5', '2,843,273', '0.43', 115): 'seen',
#  ('North Zone', 'Indicated', '0.6', '2,112,474', '0.48', 115): 'seen',
#  ('North Zone', 'Indicated', '0.7', '1,508,729', '0.54', 115): 'seen',
#  ('North Zone', 'Indicated', '0.8', '993,335', '0.60', 115): 'seen',
#  ('North Zone', 'Indicated', '0.9', '652,196', '0.66', 115): 'seen',
#  ('North Zone', 'Indicated', '1.0', '418,329', '0.72', 115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.0',
#   '13,865,642',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.1',
#   '13,808,816',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.2',
#   '13,740,485',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.3',
#   '13,489,041',
#   '0.33',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.4',
#   '12,240,824',
#   '0.34',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.5',
#   '9,395,470',
#   '0.38',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.6',
#   '6,475,333',
#   '0.43',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.7',
#   '4,178,588',
#   '0.50',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.8',
#   '2,559,813',
#   '0.56',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '0.9',
#   '1,538,122',
#   '0.63',
#   115): 'seen',
#  ('Total West and North Zones',
#   'Indicated',
#   '1.0',
#   '891,845',
#   '0.70',
#   115): 'seen',
#  ('West Zone', 'Inferred', '0.0', '964,206', '0.23', 116): 'seen',
#  ('West Zone', 'Inferred', '0.1', '954,238', '0.24', 116): 'seen',
#  ('West Zone', 'Inferred', '0.2', '894,044', '0.25', 116): 'seen',
#  ('West Zone', 'Inferred', '0.3', '831,012', '0.26', 116): 'seen',
#  ('West Zone', 'Inferred', '0.4', '699,164', '0.28', 116): 'seen',
#  ('West Zone', 'Inferred', '0.5', '464,852', '0.32', 116): 'seen',
#  ('West Zone', 'Inferred', '0.6', '264,611', '0.39', 116): 'seen',
#  ('West Zone', 'Inferred', '0.7', '138,317', '0.46', 116): 'seen',
#  ('West Zone', 'Inferred', '0.8', '73,221', '0.53', 116): 'seen',
#  ('West Zone', 'Inferred', '0.9', '30,351', '0.63', 116): 'seen',
#  ('West Zone', 'Inferred', '1.0', '18,349', '0.72', 116): 'seen',
#  ('North Zone', 'Inferred', '0.0', '10,745', '0.26', 116): 'seen',
#  ('North Zone', 'Inferred', '0.1', '10,745', '0.26', 116): 'seen',
#  ('North Zone', 'Inferred', '0.2', '10,745', '0.26', 116): 'seen',
#  ('North Zone', 'Inferred', '0.3', '10,745', '0.26', 116): 'seen',
#  ('North Zone', 'Inferred', '0.4', '8,822', '0.28', 116): 'seen',
#  ('North Zone', 'Inferred', '0.5', '5,599', '0.32', 116): 'seen',
#  ('North Zone', 'Inferred', '0.6', '2,007', '0.39', 116): 'seen',
#  ('North Zone', 'Inferred', '0.7', '391', '0.57', 116): 'seen',
#  ('North Zone', 'Inferred', '0.8', '391', '0.57', 116): 'seen',
#  ('North Zone', 'Inferred', '0.9', '109', '0.73', 116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.0',
#   '974,951',
#   '0.23',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.1',
#   '964,983',
#   '0.24',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.2',
#   '904,789',
#   '0.25',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.3',
#   '841,757',
#   '0.26',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.4',
#   '707,986',
#   '0.28',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.5',
#   '470,451',
#   '0.32',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.6',
#   '266,618',
#   '0.39',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.7',
#   '138,708',
#   '0.46',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.8',
#   '73,612',
#   '0.53',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '0.9',
#   '30,460',
#   '0.63',
#   116): 'seen',
#  ('Total West and North Zones',
#   'Inferred',
#   '1.0',
#   '18,349',
#   '0.72',
#   116): 'seen',
#  ('Fire Tower West', 'Indicated', '0.3', '9,110,400', '0.32', 117): 'seen',
#  ('Fire Tower North', 'Indicated', '0.3', '4,321,900', '0.35', 117): 'seen',
#  ('Total Indicated', 'Indicated', '0.3', '13,432,300', '0.33', 117): 'seen',
#  ('Fire Tower West', 'Inferred', '0.3', '813,000', '0.26', 117): 'seen',
#  ('Fire Tower North', 'Inferred', '0.3', '10,700', '0.26', 117): 'seen',
#  ('Total Inferred', 'Inferred', '0.3', '823,700', '0.26', 117): 'seen',
#  ('Total Fire Tower Zone',
#   'Inferred',
#   '0.3',
#   '13,074,438',
#   '0.35',
#   44): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.0', '9,391,828', '0.31', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.1', '9,335,719', '0.31', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.2', '9,281,108', '0.31', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.3', '9,148,912', '0.32', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.4', '8,487,233', '0.33', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.5', '6,552,197', '0.36', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.6', '4,362,858', '0.41', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.7', '2,669,859', '0.47', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.8', '1,566,478', '0.54', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '0.9', '885,926', '0.61', 115): 'seen',
#  ('West Zone Indicated', 'Indicated', '1.0', '473,516', '0.67', 115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.0',
#   '4,473,814',
#   '0.34',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.1',
#   '4,473,097',
#   '0.34',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.2',
#   '4,459,377',
#   '0.34',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.3',
#   '4,340,129',
#   '0.35',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.4',
#   '3,753,591',
#   '0.38',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.5',
#   '2,843,273',
#   '0.43',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.6',
#   '2,112,474',
#   '0.48',
#   115): 'seen',
#  ('North Zone Indicated',
#   'Indicated',
#   '0.7',
#   '1,508,729',
#   '0.54',
#   115): 'seen',
#  ('North Zone Indicated', 'Indicated', '0.8', '993,335', '0.60', 115): 'seen',
#  ('North Zone Indicated', 'Indicated', '0.9', '652,196', '0.66', 115): 'seen',
#  ('North Zone Indicated', 'Indicated', '1.0', '418,329', '0.72', 115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.0',
#   '13,865,642',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.1',
#   '13,808,816',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.2',
#   '13,740,485',
#   '0.32',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.3',
#   '13,489,041',
#   '0.33',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.4',
#   '12,240,824',
#   '0.34',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.5',
#   '9,395,470',
#   '0.38',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.6',
#   '6,475,333',
#   '0.43',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.7',
#   '4,178,588',
#   '0.50',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.8',
#   '2,559,813',
#   '0.56',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '0.9',
#   '1,538,122',
#   '0.63',
#   115): 'seen',
#  ('Total West and North Zones Indicated',
#   'Indicated',
#   '1.0',
#   '891,845',
#   '0.70',
#   115): 'seen',
#  ('West Zone', 'Inferred', 0.0, 964206, 0.23, 116): 'seen',
#  ('West Zone', 'Inferred', 0.1, 954238, 0.24, 116): 'seen',
#  ('West Zone', 'Inferred', 0.2, 894044, 0.25, 116): 'seen',
#  ('West Zone', 'Inferred', 0.3, 831012, 0.26, 116): 'seen',
#  ('West Zone', 'Inferred', 0.4, 699164, 0.28, 116): 'seen',
#  ('West Zone', 'Inferred', 0.5, 464852, 0.32, 116): 'seen',
#  ('West Zone', 'Inferred', 0.6, 264611, 0.39, 116): 'seen',
#  ('West Zone', 'Inferred', 0.7, 138317, 0.46, 116): 'seen',
#  ('West Zone', 'Inferred', 0.8, 73221, 0.53, 116): 'seen',
#  ('West Zone', 'Inferred', 0.9, 30351, 0.63, 116): 'seen',
#  ('West Zone', 'Inferred', 1.0, 18349, 0.72, 116): 'seen',
#  ('North Zone', 'Inferred', 0.0, 10745, 0.26, 116): 'seen',
#  ('North Zone', 'Inferred', 0.1, 10745, 0.26, 116): 'seen',
#  ('North Zone', 'Inferred', 0.2, 10745, 0.26, 116): 'seen',
#  ('North Zone', 'Inferred', 0.3, 10745, 0.26, 116): 'seen',
#  ('North Zone', 'Inferred', 0.4, 8822, 0.28, 116): 'seen',
#  ('North Zone', 'Inferred', 0.5, 5599, 0.32, 116): 'seen',
#  ('North Zone', 'Inferred', 0.6, 2007, 0.39, 116): 'seen',
#  ('North Zone', 'Inferred', 0.7, 391, 0.57, 116): 'seen',
#  ('North Zone', 'Inferred', 0.8, 391, 0.57, 116): 'seen',
#  ('North Zone', 'Inferred', 0.9, 109, 0.73, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.0, 974951, 0.23, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.1, 964983, 0.24, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.2, 904789, 0.25, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.3, 841757, 0.26, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.4, 707986, 0.28, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.5, 470451, 0.32, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.6, 266618, 0.39, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.7, 138708, 0.46, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.8, 73612, 0.53, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 0.9, 30460, 0.63, 116): 'seen',
#  ('Total West and North Zones', 'Inferred', 1.0, 18349, 0.72, 116): 'seen'}

# %%
mineral_inventory = {}
mineral_inventory['MineralInventory'] = []
idx = 0

    
for inner_sec in overall_dict:
    inner_dict = {}
    grade_dict = {}
    page_ref = {}
    zone = inner_sec[0]
    category = inner_sec[1]
    cut_off = inner_sec[2]
    tonnage = str(inner_sec[3]).replace(',', '')
    grade = inner_sec[4]
    page_num = inner_sec[5]
    contained_metal = int(tonnage) * float(grade)
    page_ref['page'] = page_num
    grade_dict['grade_unit'] = 'percent'
    grade_dict['grade_value'] = grade
    inner_dict["id"] = idx
    inner_dict['commodity'] = primary_commodity
    inner_dict['category'] = category
    inner_dict['ore'] = tonnage
    inner_dict['grade'] = grade_dict
    inner_dict['cutoff_grade'] = cut_off
    inner_dict['contained_metal'] = contained_metal
    inner_dict['reference'] = page_ref
    inner_dict['date'] = date.today().strftime("%Y-%m-%d")
    mineral_inventory['MineralInventory'].append(inner_dict)
    idx += 1

# %%
# mineral_inventory

# %%
## create json file
combined = [deposit_types, mineral_inventory]
with open(f"{pdf_name[:-4]}.json", "w") as outfile:
    json.dump(combined, outfile)

# %%
import pandas as pd
import json
import re
import csv
import os
import copy
from datetime import datetime
import glob
import numpy as np
from reportlab.lib import colors
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle, Spacer, Paragraph
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# %%
def collect_json_files(directory):
    json_files = []
    for file_path in glob.glob(os.path.join(directory, '*.json')):
         json_files.append(os.path.basename(file_path))
    return json_files

# %%
def read_csv_to_dict(file_path):
    data_dict_list = []
    
    with open(file_path, mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        
        for row in csv_reader:
            data_dict_list.append(dict(row))
    
    return data_dict_list

# %%
def select_keys(d, keys):
    selected = {}
    for key in keys:
        value = d
        for subkey in key.split('.'):
            if isinstance(value, dict) and subkey in value:
                value = value[subkey]
            else:
                value = None
                break
        selected[key] = value
    return selected

# %%
 def get_deposit_types(json_data):   
    minmod_deposit_types = read_csv_to_dict("./codes/minmod_deposit_types.csv")
    deposit_id = {}
    for key in minmod_deposit_types:
        deposit_id[key['Minmod ID']] = key['Deposit type']

    data = []
    for item in json_data['deposit_type_candidate']:
        row = {
            "observed deposit type": item.get('observed_name') if 'observed_name' in item else None,
            "normalized id": deposit_id.get(item.get('normalized_uri').split('/')[-1]) if 'normalized_uri' in item and item.get('normalized_uri').split('/')[-1] in deposit_id else None
        }
        data.append(row)

    deposit_types = pd.DataFrame(data)
    return deposit_types

# %%
def get_document_ref(json_data):
    if 'MineralInventory' in json_data and json_data['MineralInventory']:
        if 'reference' in json_data['MineralInventory'][0] and 'document' in json_data['MineralInventory'][0]['reference']:
            document_ref = json_data['MineralInventory'][0]['reference']['document']
            document_df = pd.DataFrame.from_dict(document_ref, orient='index').T
            return document_df
    # If the 'document' key does not exist, or if any of the necessary keys are missing, return None or raise an error
    return pd.DataFrame()

# %%
def get_mineral_site(json_data):
    selected_keys = ["source_id", "name", "location_info.location","location_info.country", 
                     "location_info.crs", "location_info.state_or_province"]

    mineral_site = pd.DataFrame(select_keys(json_data, selected_keys), index=[0])
    return mineral_site

# %%
def get_mineral_inventory(json_data):
    minmod_commodities = read_csv_to_dict("./codes/minmod_commodities.csv")
    commodities = {}
    for key in minmod_commodities:
        commodities[key['minmod_id']] = key['CommodityinGeoKb']

    minmod_units = read_csv_to_dict("./codes/minmod_units.csv")
    correct_units = {}
    for key in minmod_units:
        correct_units[key['minmod_id']] =  key['unit name']

    # Extracting required fields with cutoff_unit and cutoff_value
    data = []
    for item in json_data['MineralInventory']:
        row = {
            "zone": item.get("zone") if "zone" in item else None,
            "page_number": item["reference"]["page_info"][0]["page"] if "reference" in item and "page_info" in item["reference"] and item["reference"]["page_info"] else None,
            "commodity": commodities[item["commodity"].split('/')[-1]] if "commodity" in item else None,
            "category": categories if categories else None,
            "ore_unit": correct_units[item["ore"]["ore_unit"].split('/')[-1]] if "ore" in item and "ore_unit" in item["ore"] else None,
            "ore_value": item["ore"]["ore_value"] if "ore" in item and "ore_value" in item["ore"] else None,
            "grade_unit": correct_units[item["grade"]["grade_unit"].split('/')[-1]] if "grade" in item and "grade_unit" in item["grade"] else None,
            "grade_value": item["grade"]["grade_value"] if "grade" in item and "grade_value" in item["grade"] else None,
            "cutoff_unit": correct_units[item["cutoff_grade"]["grade_unit"].split('/')[-1]] if "cutoff_grade" in item and "grade_unit" in item["cutoff_grade"] else None,
            "cutoff_value": item["cutoff_grade"]["grade_value"] if "cutoff_grade" in item and "grade_value" in item["cutoff_grade"] else None
        }
        data.append(row)

    # Creating DataFrame
    mineral_inventory = pd.DataFrame(data)
    return mineral_inventory

# %%
def create_pdf_with_tables(dataframes, output_file):
    doc = SimpleDocTemplate(output_file, pagesize=letter)
    elements = []
    styles = getSampleStyleSheet()

    # Define a style for wrapped text inside table cells
    cell_style = styles['Normal']
    cell_style.wordWrap = 'CJK'  # Use 'CJK' word wrapping which wraps on any character

    for name, dataframe in dataframes.items():
        # Add title above each table
        title_style = ParagraphStyle('TitleStyle', parent=styles['Normal'], alignment=0, fontName='Helvetica-Bold')  # Left alignment and bold font
        title = Paragraph(name, title_style)
        elements.append(title)
        
        # Convert DataFrame to list of lists
        # Ensure each cell in the dataframe is wrapped with a Paragraph object
    
        if len(dataframe.columns)>0:
            table_data = [[Paragraph(str(cell), cell_style) for cell in dataframe.columns]]  # Header row
            for row in dataframe.values.tolist():
                table_data.append([Paragraph(str(cell), cell_style) for cell in row])  # Data rows

            # Calculate the width of the table to fit within the page width
            table_width = doc.width * 0.9  

            # Create table with column width calculated to fit the page

            table = Table(table_data, colWidths=[table_width / len(dataframe.columns)] * len(dataframe.columns))

            # Add style to the table
            style = TableStyle([
                ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
                ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
                ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
                ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
                ('FONTNAME', (0, 1), (-1, -1), 'Helvetica'),  # Set font to Helvetica for table data
                ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
                ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
                ('GRID', (0, 0), (-1, -1), 1, colors.black),
                ('TEXTCOLOR', (0, 0), (-1, -1), colors.black),  # Set text color to black
                ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black),  # Set inner grid color
                ('BOX', (0, 0), (-1, -1), 0.25, colors.black),  # Draw a border around each cell
                ('VALIGN', (0, 0), (-1, -1), 'MIDDLE'),  # Center text vertically
                ('ALIGN', (0, 0), (-1, -1), 'CENTER'),  # Center text horizontally
                ('FONTNAME', (0, 0), (-1, -1), 'Helvetica'),  # Set font to Helvetica for all cells
                ('SIZE', (0, 0), (-1, -1), 9),  # Set initial font size to 9
                ('TEXTFONT', (0, 0), (-1, -1), 'Helvetica'),  # Set font to Helvetica for all cells
                ('LEADING', (0, 0), (-1, -1), 9),  # Set initial leading (line spacing) to 9
                ('BACKGROUND', (0, 0), (-1, 0), colors.gray)  # Set header row background color
            ])

            table.setStyle(style)
            elements.append(table)

            # Add space between tables
            elements.append(Spacer(1, 24))

        # Build PDF with all tables
    doc.build(elements)

# %%
folder_path = '../extracted/nickel_extractions/'
files = collect_json_files(folder_path)
print(files)
# Out:
# ['Maturi_Ni_Cu_6-2006_summary_20240210_145519-checkpoint.json', 'Narrows_PGM_10-2003_summary_20240227_125734.json', 'Thunder_Bay_North_Pt_Pd_Au_Ag_Cu_Ni_12-2021_summary_20240214_122140.json', 'Ban_Phuc_Ni_2-2013_summary_20240213_153106.json', 'Shakespeare_Cu_Ni_1-2022_summary_20240214_164906.json', 'Lorraine_Ni_Cu_PGM_1-2003_summary_20240215_142412.json', 'Chidliak_diamond_6-2014_Canada_Nunavut_summary_20240227_094433.json', 'Tamarack_North_Ni_Cu__3-2020_PEA_summary_20240213_100524.json', 'Thunder_Bay_North_Ni_Cu_PGE_3-2011_summary_20240214_133401.json', 'Queensland_Ni_Co_1-2010_summary_20240215_145248.json', 'Lantinen_Koillismaa_Ni_Cu_PGE_Au_3-2017_summary_20240215_141009.json', 'Chiniguchi_River_Ni_Cu_PGM_3-2009_summary_20240227_101352.json', 'Tamarack_North_Cu_Ni_PGE_8-2014_summary_20240213_083845.json', 'Tamarack_North_Ni_Cu_Co_Pt_Pd_Au_12-2018_PEA_summary_20240213_122908.json', 'Casson_Lake_Ni_Cu_PGM_10-2002_summary_20240215_095428.json', 'Tamarack_North_Ni_Cu_Co_1-2021_summary_20240213_115530.json', 'Birch_Lake-Maturi_Ni_Cu_10-2006_summary_20240209_124102.json', 'Nickel_Royale_Ni_12-2003_summary_20240319_165526.json', 'Alexo_Ni_11-2010_summary_20240215_092632.json', 'Nokomis_Ni_Cu_PGM_12-2009_summary_20240214_155510.json', 'Stellar_Ni_Cu_2-2006_summary_20240215_150413.json', 'Nanuq_diamond_11-2008_summary_20240215_143445.json', 'Crawford_Ni_Co_3-2020_summary_20240215_102352.json', 'Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_6-2012_summary_20240213_081908.json', 'Keveri_Cu_Au_7-2019_summary_20240215_120146.json', 'HN4_N100_Ni_10-2021_summary_20240215_105859.json', 'Midrim_Ni_Cu_PGM_2-2003_summary_20240227_110555.json', 'Nickel_Lake_Ni_Cu_2-2003_summary_20240215_144205.json', 'Hitura_Ni_10-2010_summary_20240214_142004.json', 'Sunrise_Ni_Co_6-2018_summary_20240215_155755.json', 'Kenbridge_Ni_Cu_4-2007_summary_20240215_115136.json', 'Sudbury_Basin_Ni_Cu_11-2001_summary_20240215_152454.json', 'Isortoq_Fe_Ti_V_4-2012_summary_20240227_103640.json', 'Maturi_Ni_Cu_6-2006_summary_20240210_145519.json', 'Genesis_Ni_Cu_PGE_11-2018__summary_20240227_102725.json', 'Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_9-2012_summary_20240212_180111.json', 'Bucko_Lake_Ni_10-2012_summary_20240214_105417.json', 'Lansdowne_House_Ni_Cu_PGM_1-2003_summary_20240215_135008.json']

# %%
for file in files:
    print(f"working on file: {file}")
    file_path = folder_path + file
    filename = file[:-3]
    with open(file_path, 'r') as f:
        # Load the JSON data into a Python dictionary
        data = json.load(f)

    # Now 'data' contains the contents of the JSON file
    json_data = data['MineralSite'][0]
    document_df = get_document_ref(json_data)
    mineral_site = get_mineral_site(json_data)
    mineral_inventory = get_mineral_inventory(json_data)
    deposit_types = get_deposit_types(json_data)
    data_dict = {'Document Reference':document_df, 'Mineral Site ':mineral_site, 
                 'Mineral Inventory':mineral_inventory, 'Deposit Types': deposit_types}
    create_pdf_with_tables(data_dict, f'./created_pdf/{filename}.pdf')
    print(f"Finished file {file}")
# Out:
# working on file: Narrows_PGM_10-2003_summary_20240227_125734.json
# {'observed_name': 'stratigraphically controlled', 'normalized_uri': 'https://minmod.isi.edu/resource/', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'intrusion-hosted', 'normalized_uri': 'https://minmod.isi.edu/resource/', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'shear and/or quartz vein-hosted', 'normalized_uri': 'https://minmod.isi.edu/resource/', 'source': 'report', 'confidence': 0.3333333333333333}
# Finished file Narrows_PGM_10-2003_summary_20240227_125734.json
# working on file: Thunder_Bay_North_Pt_Pd_Au_Ag_Cu_Ni_12-2021_summary_20240214_122140.json
# {'observed_name': 'A meteorite-impact mafic melt sheet containing massive basal sulphide deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'Rift and continental flood basalt-associated mafic sills dyke-like bodies and chonoliths', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'Komatiite (magnesium-rich) ultramafic volcanic flows and related sill-like intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'Other mafic/ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'Reef-type Stratiform PGE deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'Magmatic breccia/contact type deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# Finished file Thunder_Bay_North_Pt_Pd_Au_Ag_Cu_Ni_12-2021_summary_20240214_122140.json
# working on file: Ban_Phuc_Ni_2-2013_summary_20240213_153106.json
# {'observed_name': 'Low Grade Disseminated Type Sulphides (DISS) in Dunite', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 1}
# Finished file Ban_Phuc_Ni_2-2013_summary_20240213_153106.json
# working on file: Shakespeare_Cu_Ni_1-2022_summary_20240214_164906.json
# {'observed_name': 'Nipissing model', 'normalized_uri': '', 'source': 'report', 'confidence': 0.5}
# {'observed_name': 'Sudbury Offset model', 'normalized_uri': '', 'source': 'report', 'confidence': 0.5}
# Finished file Shakespeare_Cu_Ni_1-2022_summary_20240214_164906.json
# working on file: Lorraine_Ni_Cu_PGM_1-2003_summary_20240215_142412.json
# {'observed_name': 'Magmatic nickel-copper sulphide-type deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Astrobleme-associated', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Rift and continental flood basalt-related', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Komatiite-hosted', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Other tholeiitic intrusion-hosted', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# Finished file Lorraine_Ni_Cu_PGM_1-2003_summary_20240215_142412.json
# working on file: Chidliak_diamond_6-2014_Canada_Nunavut_summary_20240227_094433.json
# {'observed_name': 'Diamond Deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Magmatic Nickel-Copper-Platinum Group Element Deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Metamorphosed Massive Sulphide Deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.3333333333333333}
# Finished file Chidliak_diamond_6-2014_Canada_Nunavut_summary_20240227_094433.json
# working on file: Tamarack_North_Ni_Cu__3-2020_PEA_summary_20240213_100524.json
# {'observed_name': 'magmatic nickel-copper-PGE sulphide mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q482', 'confidence': 1, 'source': 'SME'}
# Finished file Tamarack_North_Ni_Cu__3-2020_PEA_summary_20240213_100524.json
# working on file: Thunder_Bay_North_Ni_Cu_PGE_3-2011_summary_20240214_133401.json
# {'observed_name': 'nickel-copper (PGE) deposit', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'PGE deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'meteorite-impact mafic melt sheet', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'rift and continental flood basalt-associated mafic sills and dyke-like bodies', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'komatiite ultramafic volcanic flows and related sill-like intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# {'observed_name': 'other mafic/ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.16666666666666666}
# Finished file Thunder_Bay_North_Ni_Cu_PGE_3-2011_summary_20240214_133401.json
# working on file: Queensland_Ni_Co_1-2010_summary_20240215_145248.json
# {'observed_name': 'nickel sulphide mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.25}
# {'observed_name': 'hydrothermally altered serpentinites', 'normalized_uri': '', 'source': 'report', 'confidence': 0.25}
# {'observed_name': 'Aguablanca Deposit', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.25}
# {'observed_name': 'Avebury Deposit', 'normalized_uri': '', 'source': 'report', 'confidence': 0.25}
# Finished file Queensland_Ni_Co_1-2010_summary_20240215_145248.json
# working on file: Lantinen_Koillismaa_Ni_Cu_PGE_Au_3-2017_summary_20240215_141009.json
# {'observed_name': 'reef-type', 'normalized_uri': '', 'source': 'report', 'confidence': 1.0}
# Finished file Lantinen_Koillismaa_Ni_Cu_PGE_Au_3-2017_summary_20240215_141009.json
# working on file: Chiniguchi_River_Ni_Cu_PGM_3-2009_summary_20240227_101352.json
# {'observed_name': 'Contact-breccia type Ni-Cu-PGE mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'source': 'report', 'confidence': 1.0}
# Finished file Chiniguchi_River_Ni_Cu_PGM_3-2009_summary_20240227_101352.json
# working on file: Tamarack_North_Cu_Ni_PGE_8-2014_summary_20240213_083845.json
# {'observed_name': 'magmatic nickel-copper-PGE sulphide mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q482', 'confidence': 1, 'source': 'SME'}
# Finished file Tamarack_North_Cu_Ni_PGE_8-2014_summary_20240213_083845.json
# working on file: Tamarack_North_Ni_Cu_Co_Pt_Pd_Au_12-2018_PEA_summary_20240213_122908.json
# {'observed_name': 'magmatic nickel-copper-PGE sulphide mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q482', 'confidence': 1, 'source': 'SME'}
# Finished file Tamarack_North_Ni_Cu_Co_Pt_Pd_Au_12-2018_PEA_summary_20240213_122908.json
# working on file: Casson_Lake_Ni_Cu_PGM_10-2002_summary_20240215_095428.json
# {'observed_name': 'Noritic rocks associated with an astrobleme', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Intrusive equivalents of flood basalts associated with intracontinental rifting', 'normalized_uri': 'https://minmod.isi.edu/resource/Q482', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Tholeiitic intrusions hosting nickel deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Komatiitic lavas and related ultramafic intrusions nickel deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Syn-kinematic tholeiitic intrusions within Phanerozoic orogens', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# Finished file Casson_Lake_Ni_Cu_PGM_10-2002_summary_20240215_095428.json
# working on file: Tamarack_North_Ni_Cu_Co_1-2021_summary_20240213_115530.json
# {'observed_name': 'magmatic nickel-copper-PGE sulphide mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q482', 'confidence': 1, 'source': 'SME'}
# Finished file Tamarack_North_Ni_Cu_Co_1-2021_summary_20240213_115530.json
# working on file: Birch_Lake-Maturi_Ni_Cu_10-2006_summary_20240209_124102.json
# {'observed_name': 'magmatic nickel- copper-platinum group element (PGE)', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'confidence': 1, 'source': 'SME'}
# Finished file Birch_Lake-Maturi_Ni_Cu_10-2006_summary_20240209_124102.json
# working on file: Alexo_Ni_11-2010_summary_20240215_092632.json
# {'observed_name': 'Magmatic Ni-Cu deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.5}
# {'observed_name': 'Komatite-hosted Ni-Cu deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 0.5}
# Finished file Alexo_Ni_11-2010_summary_20240215_092632.json
# working on file: Nokomis_Ni_Cu_PGM_12-2009_summary_20240214_155510.json
# {'observed_name': 'Cu-Ni-PGE', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 1.0}
# Finished file Nokomis_Ni_Cu_PGM_12-2009_summary_20240214_155510.json
# working on file: Stellar_Ni_Cu_2-2006_summary_20240215_150413.json
# {'observed_name': 'Ni-Cu-Co-PGE massive sulphide', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Magmatic Cu-Ni massive sulphide', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Besshi-style massive sulphide', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Tholeiitic intrusion-hosted Ni-Cu', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'SKARN', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# Finished file Stellar_Ni_Cu_2-2006_summary_20240215_150413.json
# working on file: Nanuq_diamond_11-2008_summary_20240215_143445.json
# Finished file Nanuq_diamond_11-2008_summary_20240215_143445.json
# working on file: Crawford_Ni_Co_3-2020_summary_20240215_102352.json
# {'observed_name': 'Intrusion-hosted magmatic Ni-Co-PGE deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 1.0}
# Finished file Crawford_Ni_Co_3-2020_summary_20240215_102352.json
# working on file: Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_6-2012_summary_20240213_081908.json
# {'observed_name': 'magmatic nickel- copper-platinum group element (PGE)', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'confidence': 1, 'source': 'SME'}
# Finished file Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_6-2012_summary_20240213_081908.json
# working on file: Keveri_Cu_Au_7-2019_summary_20240215_120146.json
# {'observed_name': 'Porphyry-style Cu-Au mineralisation', 'normalized_uri': '', 'source': 'report', 'confidence': 1.0}
# Finished file Keveri_Cu_Au_7-2019_summary_20240215_120146.json
# working on file: HN4_N100_Ni_10-2021_summary_20240215_105859.json
# {'observed_name': 'Podiform chromite (M03) within the Trembleur ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Ultramafic-hosted asbestos (M06) within serpentinized Trembleur ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Jade (Q01) within serpentinized Trembleur ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Au-Quartz Veins (I01) within listwanite alteration zones in the Trembleur ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# {'observed_name': 'Dunitic nickel-copper (USGS 6b) or Limassol Forest Co-Ni (USGS 8c) within serpentinized Trembleur ultramafic intrusions', 'normalized_uri': '', 'source': 'report', 'confidence': 0.2}
# Finished file HN4_N100_Ni_10-2021_summary_20240215_105859.json
# working on file: Midrim_Ni_Cu_PGM_2-2003_summary_20240227_110555.json
# {'observed_name': 'Magmatic Ni-Cu-PGM deposits associated with mafic-ultramafic intrusions', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 1.0}
# Finished file Midrim_Ni_Cu_PGM_2-2003_summary_20240227_110555.json
# working on file: Nickel_Lake_Ni_Cu_2-2003_summary_20240215_144205.json
# {'observed_name': 'magmatic nickel-copper-platinum group metal sulphide deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.5}
# {'observed_name': 'massive sulphide deposits', 'normalized_uri': '', 'source': 'report', 'confidence': 0.5}
# Finished file Nickel_Lake_Ni_Cu_2-2003_summary_20240215_144205.json
# working on file: Hitura_Ni_10-2010_summary_20240214_142004.json
# {'observed_name': 'Ultramafic-associated nickel (copper-cobalt-platinum group elements) deposit', 'normalized_uri': '', 'source': 'report', 'confidence': 1.0}
# Finished file Hitura_Ni_10-2010_summary_20240214_142004.json
# working on file: Sunrise_Ni_Co_6-2018_summary_20240215_155755.json
# {'observed_name': 'nickel laterite', 'normalized_uri': 'https://minmod.isi.edu/resource/Q319', 'source': 'report', 'confidence': 1.0}
# Finished file Sunrise_Ni_Co_6-2018_summary_20240215_155755.json
# working on file: Kenbridge_Ni_Cu_4-2007_summary_20240215_115136.json
# {'observed_name': 'Magmatic sulphide accumulation', 'normalized_uri': 'https://minmod.isi.edu/resource/Q476', 'source': 'report', 'confidence': 1.0}
# Finished file Kenbridge_Ni_Cu_4-2007_summary_20240215_115136.json
# working on file: Sudbury_Basin_Ni_Cu_11-2001_summary_20240215_152454.json
# {'observed_name': 'Contact Deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Footwall Deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Offset Dyke Deposits', 'normalized_uri': 'https://minmod.isi.edu/resource/Q423', 'source': 'report', 'confidence': 0.3333333333333333}
# Finished file Sudbury_Basin_Ni_Cu_11-2001_summary_20240215_152454.json
# working on file: Isortoq_Fe_Ti_V_4-2012_summary_20240227_103640.json
# {'observed_name': 'Igneous Cumulate Deposits (ICD)', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Iron Skarn (magnetite-dominant)', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Kiruna-type Fe-oxide-apatite', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Banded Iron Formations (BIFs) - magnetite-quartz-carbonate', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Banded Iron Formations (BIFs) - hematite-quartz, weakly Fe-enriched in fold hinges', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Banded Iron Formations (BIFs) - silica-depleted magnetite-carbonate', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Banded Iron Formations (BIFs) - silica-carbonate-depleted hematite-rich with platy hematite and martite (Proterozoic giants)', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Laterites (goethite-martite-clay)', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# {'observed_name': 'Transported ores (channel-fill and scree)', 'normalized_uri': '', 'source': 'report', 'confidence': 0.1111111111111111}
# Finished file Isortoq_Fe_Ti_V_4-2012_summary_20240227_103640.json
# working on file: Maturi_Ni_Cu_6-2006_summary_20240210_145519.json
# {'observed_name': 'magmatic nickel- copper-platinum group element (PGE)', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'confidence': 1, 'source': 'SME'}
# Finished file Maturi_Ni_Cu_6-2006_summary_20240210_145519.json
# working on file: Genesis_Ni_Cu_PGE_11-2018__summary_20240227_102725.json
# Finished file Genesis_Ni_Cu_PGE_11-2018__summary_20240227_102725.json
# working on file: Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_9-2012_summary_20240212_180111.json
# {'observed_name': 'magmatic nickel- copper-platinum group element (PGE)', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'confidence': 1, 'source': 'SME'}
# Finished file Maturi-Birch_Lake-Spruce_Road_Ni_Cu_PGE_9-2012_summary_20240212_180111.json
# working on file: Bucko_Lake_Ni_10-2012_summary_20240214_105417.json
# {'observed_name': 'Thompson-style mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q403', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Birchtree-style mineralization', 'normalized_uri': 'https://minmod.isi.edu/resource/Q403', 'source': 'report', 'confidence': 0.3333333333333333}
# {'observed_name': 'Disseminated to semi-massive sulfides in serpentinized peridotite', 'normalized_uri': 'https://minmod.isi.edu/resource/Q403', 'source': 'report', 'confidence': 0.3333333333333333}
# Finished file Bucko_Lake_Ni_10-2012_summary_20240214_105417.json
# working on file: Lansdowne_House_Ni_Cu_PGM_1-2003_summary_20240215_135008.json
# {'observed_name': 'Layered mafic-ultramafic sequences hosting Cu-Ni-PGM occurrences', 'normalized_uri': 'https://minmod.isi.edu/resource/Q478', 'source': 'report', 'confidence': 1.0}
# Finished file Lansdowne_House_Ni_Cu_PGM_1-2003_summary_20240215_135008.json
